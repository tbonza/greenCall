# %% [markdown]
# # Elasticsearch Document Conversion
#
# The Elasticsearch Document Conversion from our Search API results appears to be a pain point.
# This notebook is meant to serve as root cause analysis of the issue

# %% [markdown]
# ## Settings Variables

# %%
# Maximum number of query items to request from API
QUERY_LIMIT = 20

# Maximum number or requests deferred
MAX_RUN = 20

# This many seconds will expire between requests sent
RATE_LIMIT = 1

# Path to original excel file, converted to CSV
filepath = 'examples/finance_demo.csv'

# Path to converted file to be used for API requests
outpath = 'examples/ipython_demo.json'

# results returned from the API via the networking engine
resultspath = 'results.json'

# Specify a document template for Elasticsearch
esformat = {
            "_index": "ipythonsearch",
            "_type": "website",
            "_id": None,
            "_source": ""
        }

# %% [markdown]
# ## Reading JSON from Search API Results

# %%
import itertools
import string
import json
from elasticsearch import Elasticsearch,helpers

from greencall.utils.loadelastic import read_json, prepare_all_documents
from greencall.csvclean.inputCsv import read_csv

# Connect to Elasticsearch
es = Elasticsearch()

# Read results from the Search API
results = read_json(resultspath)

# Take the length of the results as a sanity check
len(results)
# Out:
# 20

# %% [markdown]
# ## Reviewing Results from the Google Search API

# %%
# take a look at the first document

print("key:\n {}\n".format(results.keys()[0]))
print("result:\n {}".format(results[results.keys()[0]]))
# Out:
# key:
#  11111437
#
# result:
#  {
#  "kind": "customsearch#search",
#  "url": {
#   "type": "application/json",
#   "template": "https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&cref={cref?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json"
#  },
#  "queries": {
#   "request": [
#    {
#     "title": "Google Custom Search - Akeem Dent",
#     "totalResults": "0",
#     "searchTerms": "Akeem Dent",
#     "count": 10,
#     "language": "lang_en",
#     "inputEncoding": "utf8",
#     "outputEncoding": "utf8",
#     "safe": "off",
#     "cx": "003891126258438650518:fcb7zxrqavu",
#     "filter": "1",
#     "exactTerms": "asset",
#     "dateRestrict": "'2012'"
#    }
#   ]
#  },
#  "searchInformation": {
#   "searchTime": 0.161848,
#   "formattedSearchTime": "0.16",
#   "totalResults": "0",
#   "formattedTotalResults": "0"
#  }
# }

# %% [markdown]
# ** Output from the First Result**
#
# Here we can see that the first result includes 0 total results. It looks like
# we have some generic fields that seem to be search meta-data. This initially
# looks like it would be 3 elasticsearch documents but it may make more sense
# to condense the meta-data into one ES document.
#
# Let's take a look at results that include search results next

# %%
# result that contains search hits
import codecs

print("key:\n {}\n".format(results.keys()[1]))
print("value:\n {}".format(codecs.encode(results[results.keys()[1]],'ascii','ignore')))
# Out:
# key:
#  11111253
#
# value:
#  {
#  "kind": "customsearch#search",
#  "url": {
#   "type": "application/json",
#   "template": "https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&cref={cref?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json"
#  },
#  "queries": {
#   "nextPage": [
#    {
#     "title": "Google Custom Search - Jeremy Clark",
#     "totalResults": "6020",
#     "searchTerms": "Jeremy Clark",
#     "count": 10,
#     "startIndex": 11,
#     "language": "lang_en",
#     "inputEncoding": "utf8",
#     "outputEncoding": "utf8",
#     "safe": "off",
#     "cx": "003891126258438650518:fcb7zxrqavu",
#     "filter": "1",
#     "exactTerms": "asset",
#     "dateRestrict": "'2012'"
#    }
#   ],
#   "request": [
#    {
#     "title": "Google Custom Search - Jeremy Clark",
#     "totalResults": "6020",
#     "searchTerms": "Jeremy Clark",
#     "count": 10,
#     "startIndex": 1,
#     "language": "lang_en",
#     "inputEncoding": "utf8",
#     "outputEncoding": "utf8",
#     "safe": "off",
#     "cx": "003891126258438650518:fcb7zxrqavu",
#     "filter": "1",
#     "exactTerms": "asset",
#     "dateRestrict": "'2012'"
#    }
#   ]
#  },
#  "context": {
#   "title": "greencall"
#  },
#  "searchInformation": {
#   "searchTime": 0.509002,
#   "formattedSearchTime": "0.51",
#   "totalResults": "6020",
#   "formattedTotalResults": "6,020"
#  },
#  "items": [
#   {
#    "kind": "customsearch#result",
#    "title": "Jeremy Clark in Rio Rancho, New Mexico with Reviews & Ratings ...",
#    "htmlTitle": "\u003cb\u003eJeremy Clark\u003c/b\u003e in Rio Rancho, New Mexico with Reviews &amp; Ratings \u003cb\u003e...\u003c/b\u003e",
#    "link": "http://www.yellowpages.com/rio-rancho-nm/jeremy-clark",
#    "displayLink": "www.yellowpages.com",
#    "snippet": "Results 1 - 13 of 13 ... Find 13 listings related to Jeremy Clark in Rio Rancho on YP.com. See reviews ... \nJeremy Edmonds MD. 401 San ... Clark Asset Management.",
#    "htmlSnippet": "Results 1 - 13 of 13 \u003cb\u003e...\u003c/b\u003e Find 13 listings related to \u003cb\u003eJeremy Clark\u003c/b\u003e in Rio Rancho on YP.com. See reviews ... \u003cbr\u003e\nJeremy Edmonds MD. 401 San ... Clark \u003cb\u003eAsset\u003c/b\u003e Management.",
#    "cacheId": "e2kOwf6OQDYJ",
#    "formattedUrl": "www.yellowpages.com/rio-rancho-nm/jeremy-clark",
#    "htmlFormattedUrl": "www.yellowpages.com/rio-rancho-nm/\u003cb\u003ejeremy\u003c/b\u003e-\u003cb\u003eclark\u003c/b\u003e",
#    "pagemap": {
#     "postaladdress": [
#      {
#       "streetaddress": "401 San Mateo Blvd SE",
#       "addresslocality": "Albuquerque,",
#       "addressregion": "NM",
#       "postalcode": "87108"
#      },
#      {
#       "streetaddress": "1 University Of New Mexico # 10-5560",
#       "addresslocality": "Albuquerque,",
#       "addressregion": "NM",
#       "postalcode": "87131"
#      },
#      {
#       "streetaddress": "5400 Gibson Blvd SE",
#       "addresslocality": "Albuquerque,",
#       "addressregion": "NM",
#       "postalcode": "87108"
#      },
#      {
#       "streetaddress": "4901 Lang Ave NE",
#       "addresslocality": "Albuquerque,",
#       "addressregion": "NM",
#       "postalcode": "87109"
#      },
#      {
#       "streetaddress": "4901 Lang Ave NE",
#       "addresslocality": "Albuquerque,",
#       "addressregion": "NM",
#       "postalcode": "87109"
#      },
#      {
#       "streetaddress": "3901 Atrisco Dr NW",
#       "addresslocality": "Albuquerque,",
#       "addressregion": "NM",
#       "postalcode": "87120"
#      },
#      {
#       "streetaddress": "1100 Central Ave SE",
#       "addresslocality": "Albuquerque,",
#       "addressregion": "NM",
#       "postalcode": "87106"
#      },
#      {
#       "streetaddress": "1824 Slate Ave NW",
#       "addresslocality": "Albuquerque,",
#       "addressregion": "NM",
#       "postalcode": "87104"
#      },
#      {
#       "streetaddress": "500 Marquette Ave NW # 1100",
#       "addresslocality": "Albuquerque,",
#       "addressregion": "NM",
#       "postalcode": "87102"
#      },
#      {
#       "streetaddress": "801 Vassar Dr NE",
#       "addresslocality": "Albuquerque,",
#       "addressregion": "NM",
#       "postalcode": "87106"
#      },
#      {
#       "streetaddress": "240 Burma Dr NE",
#       "addresslocality": "Albuquerque,",
#       "addressregion": "NM",
#       "postalcode": "87123"
#      },
#      {
#       "streetaddress": "1895 Bosque Farms Blvd",
#       "addresslocality": "Bosque Farms,",
#       "addressregion": "NM",
#       "postalcode": "87068"
#      },
#      {
#       "streetaddress": "1895 Bosque Farms Blvd",
#       "addresslocality": "Bosque Farms,",
#       "addressregion": "NM",
#       "postalcode": "87068"
#      },
#      {
#       "streetaddress": "730 3rd St SW",
#       "addresslocality": "Rio Rancho,",
#       "addressregion": "NM",
#       "postalcode": "87124"
#      },
#      {
#       "streetaddress": "10315 Woodland Ave NE",
#       "addresslocality": "Albuquerque,",
#       "addressregion": "NM",
#       "postalcode": "87112"
#      },
#      {
#       "addresslocality": "Albuquerque,",
#       "addressregion": "NM",
#       "postalcode": "87121"
#      }
#     ],
#     "localbusiness": [
#      {
#       "name": "Jeremy Edmonds MD",
#       "telephone": "(505) 462-7333"
#      },
#      {
#       "name": "Gonda, Jeremy M, MD",
#       "telephone": "(505) 272-6387"
#      },
#      {
#       "name": "DR Jeremy Gleeson MD",
#       "telephone": "(505) 262-7455"
#      },
#      {
#       "name": "Douglas A Clark MD",
#       "telephone": "(505) 890-8904"
#      },
#      {
#       "name": "Clark E Haskins MD",
#       "telephone": "(505) 842-8171"
#      },
#      {
#       "name": "Clark, Charles, MD",
#       "telephone": "(505) 462-7575"
#      },
#      {
#       "name": "Clark, Robert L, MD - CLOSED",
#       "telephone": "(505) 841-1234"
#      },
#      {
#       "name": "Clark, Samantha",
#       "telephone": "(505) 243-9884"
#      },
#      {
#       "name": "Clark Robert H",
#       "telephone": "(505) 842-1950"
#      },
#      {
#       "name": "Clark, Donald W, MD - CLOSED",
#       "telephone": "(505) 248-4000"
#      },
#      {
#       "name": "Clark Asset Management",
#       "telephone": "(505) 450-8780"
#      },
#      {
#       "name": "Clark, Steven J, JD",
#       "telephone": "(505) 869-2310"
#      },
#      {
#       "name": "Clark Steven J",
#       "telephone": "(505) 869-2310"
#      },
#      {
#       "name": "Home Landscaping Pros",
#       "telephone": "(844) 505-4300"
#      },
#      {
#       "name": "Chop Chop Landscaping",
#       "telephone": "(855) 712-8812"
#      },
#      {
#       "name": "Sanchez Landscaping",
#       "telephone": "(505) 604-2313"
#      },
#      {
#       "name": "J and J Landscape, LLC",
#       "telephone": "(505) 221-6061"
#      },
#      {
#       "name": "Kokopelli Landscaping Inc.",
#       "telephone": "(505) 412-4040"
#      },
#      {
#       "name": "Mountain Paradise Landscaping",
#       "telephone": "(505) 688-7782"
#      },
#      {
#       "name": "Herrera's Landscaping",
#       "telephone": "(505) 795-6439"
#      },
#      {
#       "name": "Rio Falls Property Maintenance & Repairs",
#       "telephone": "(505) 435-9880"
#      }
#     ],
#     "metatags": [
#      {
#       "charset": "utf-8",
#       "viewport": "width=device-width, initial-scale=.75, maximum-scale=1"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Clark Group Asset Management - Investing - Sherman Oaks ...",
#    "htmlTitle": "\u003cb\u003eClark\u003c/b\u003e Group \u003cb\u003eAsset\u003c/b\u003e Management - Investing - Sherman Oaks \u003cb\u003e...\u003c/b\u003e",
#    "link": "http://www.yelp.com/biz/clark-group-asset-management-sherman-oaks",
#    "displayLink": "www.yelp.com",
#    "snippet": "Clark Group Asset Management Sherman Oaks reviews by real people. Yelp is a \nfun and easy way to ... Jeremy Licht - JL Capital Management. 5.0 star rating.",
#    "htmlSnippet": "\u003cb\u003eClark\u003c/b\u003e Group \u003cb\u003eAsset\u003c/b\u003e Management Sherman Oaks reviews by real people. Yelp is a \u003cbr\u003e\nfun and easy way to ... \u003cb\u003eJeremy\u003c/b\u003e Licht - JL Capital Management. 5.0 star rating.",
#    "cacheId": "L0DgbBMQlRYJ",
#    "formattedUrl": "www.yelp.com/biz/clark-group-asset-management-sherman-oaks",
#    "htmlFormattedUrl": "www.yelp.com/biz/\u003cb\u003eclark\u003c/b\u003e-group-\u003cb\u003easset\u003c/b\u003e-management-sherman-oaks",
#    "pagemap": {
#     "cse_image": [
#      {
#       "src": "http://media1.fl.yelpcdn.com/img/logo/yelp_og_image.png"
#      }
#     ],
#     "postaladdress": [
#      {
#       "streetaddress": "15060 Ventura Blvd Ste 401",
#       "addresslocality": "Sherman Oaks",
#       "addressregion": "CA",
#       "postalcode": "91403"
#      }
#     ],
#     "localbusiness": [
#      {
#       "name": "Clark Group Asset Management",
#       "telephone": "(818) 461-9333"
#      }
#     ],
#     "metatags": [
#      {
#       "viewport": "width=1020",
#       "application-name": "Yelp",
#       "msapplication-tileimage": "http://s3-media3.fl.yelpcdn.com/assets/2/www/img/7f906850f02b/ico/win8-tile.png",
#       "msapplication-tilecolor": "#c41200",
#       "msapplication-starturl": "http://www.yelp.com/",
#       "msapplication-navbutton-color": "#c41200",
#       "msapplication-window": "width=1024;height=768",
#       "msapplication-tooltip": "Go to Yelp.com",
#       "msapplication-task": "name=Find Reviews; action-uri=/; icon-uri=http://s3-media1.fl.yelpcdn.com/assets/2/www/img/a6bbc59c7458/ico/favicon-16x16.ico",
#       "apple-itunes-app": "app-id=284910350, app-argument=yelp:///biz/ksziNjpQu-WeQV7kZF6I2Q?campaign=default&source=www&utm_campaign=default&utm_source=www",
#       "theme-color": "#c41200",
#       "fb:app_id": "97534753161",
#       "og:description": "Investing in Sherman Oaks, CA",
#       "og:image": "http://media1.fl.yelpcdn.com/img/logo/yelp_og_image.png",
#       "og:site_name": "Yelp",
#       "og:title": "Clark Group Asset Management - Sherman Oaks - Sherman Oaks, CA",
#       "og:type": "yelpyelp:business",
#       "og:url": "http://www.yelp.com/biz/clark-group-asset-management-sherman-oaks",
#       "og:image:width": "576",
#       "og:image:height": "576",
#       "twitter:app:name:googleplay": "Yelp",
#       "twitter:app:url:ipad": "yelp:///biz/ksziNjpQu-WeQV7kZF6I2Q?campaign=default&source=twitter-card&utm_campaign=default&utm_source=twitter-card",
#       "twitter:domain": "yelp.com",
#       "twitter:app:name:iphone": "Yelp",
#       "twitter:app:name:ipad": "Yelp",
#       "twitter:app:url:googleplay": "android-app://com.yelp.android/yelp-app-indexing/biz/ksziNjpQu-WeQV7kZF6I2Q?utm_medium=organic&utm_source=google",
#       "twitter:site": "@yelp",
#       "twitter:app:id:googleplay": "com.yelp.android",
#       "twitter:app:id:iphone": "id284910350",
#       "twitter:app:url:iphone": "yelp:///biz/ksziNjpQu-WeQV7kZF6I2Q?campaign=default&source=twitter-card&utm_campaign=default&utm_source=twitter-card",
#       "twitter:card": "summary",
#       "twitter:app:id:ipad": "id284910350",
#       "yelp-biz-id": "ksziNjpQu-WeQV7kZF6I2Q"
#      }
#     ],
#     "breadcrumb": [
#      {
#       "url": "Financial Services",
#       "title": "Financial Services"
#      },
#      {
#       "url": "Investing",
#       "title": "Investing"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Edward Jones - Financial Advisor: Jeremy R Clark in Cedar Rapids ...",
#    "htmlTitle": "Edward Jones - Financial Advisor: \u003cb\u003eJeremy\u003c/b\u003e R \u003cb\u003eClark\u003c/b\u003e in Cedar Rapids \u003cb\u003e...\u003c/b\u003e",
#    "link": "https://local.yahoo.com/info-66423216-edward-jones-financial-advisor-mark-a-clark-cedar-rapids",
#    "displayLink": "local.yahoo.com",
#    "snippet": "Find Edward Jones - Financial Advisor: Jeremy R Clark in Cedar Rapids with \nAddress, Phone number from Yahoo US Local. Includes Edward Jones - \nFinancial...",
#    "htmlSnippet": "Find Edward Jones - Financial Advisor: \u003cb\u003eJeremy\u003c/b\u003e R \u003cb\u003eClark\u003c/b\u003e in Cedar Rapids with \u003cbr\u003e\nAddress, Phone number from Yahoo US Local. Includes Edward Jones - \u003cbr\u003e\nFinancial&nbsp;...",
#    "cacheId": "DCBh6aAO7WMJ",
#    "formattedUrl": "https://local.yahoo.com/info-66423216-edward-jones-financial-advisor-mark -a-clark-cedar-rapids",
#    "htmlFormattedUrl": "https://local.yahoo.com/info-66423216-edward-jones-financial-advisor-mark -a-\u003cb\u003eclark\u003c/b\u003e-cedar-rapids",
#    "pagemap": {
#     "cse_image": [
#      {
#       "src": "https://s.yimg.com/tj/locals/d/misc/1.2/local2.png"
#      }
#     ],
#     "aggregaterating": [
#      {
#       "ratingvalue": "0",
#       "reviewcount": "0"
#      }
#     ],
#     "postaladdress": [
#      {
#       "streetaddress": "3136 Mount Vernon Rd Se",
#       "addresslocality": "Cedar Rapids",
#       "addressregion": "IA",
#       "postalcode": "52403"
#      }
#     ],
#     "webpage": [
#      {
#       "breadcrumb": "Find:Legal & Financial Services\u003eInvestment Services\u003eInvestment Banks\u003eEdward Jones - Financial Advisor: Jeremy R Clark"
#      }
#     ],
#     "localbusiness": [
#      {
#       "name": "Edward Jones - Financial Advisor: Jeremy R Clark",
#       "image": "https://s.yimg.com/tj/locals/d/misc/1.2/local2.png",
#       "description": "Find Edward Jones - Financial Advisor: Jeremy R Clark in Cedar Rapids with Address, Phone number from Yahoo US Local. Includes Edward Jones - Financial Advisor: Jeremy R Clark Reviews, maps..."
#      },
#      {
#       "name": "Edward Jones - Financial Advisor: Jeremy R Clark",
#       "telephone": "(319) 363-8111",
#       "url": "edwardjones.com"
#      }
#     ],
#     "metatags": [
#      {
#       "viewport": "width=device-width, initial-scale=1.0, maximum-scale=1.0, maximum-scale=1.0, user-scalable=no",
#       "handheldfriendly": "true",
#       "title": "Edward Jones - Financial Advisor: Jeremy R Clark in Cedar Rapids | Edward Jones - Financial Advisor: Jeremy R Clark 3136 Mount Vernon Rd Se, Cedar Rapids, IA 52403 Yahoo - US Local",
#       "fb:app_id": "191852587502049",
#       "og:type": "business.business",
#       "og:url": "https://local.yahoo.com/info-66423216-edward-jones-financial-advisor-jeremy-r-clark-cedar-rapids",
#       "og:title": "Edward Jones - Financial Advisor: Jeremy R Clark",
#       "og:image": "https://s.yimg.com/tj/locals/d/misc/1.2/local2.png",
#       "og:description": "Find Edward Jones - Financial Advisor: Jeremy R Clark in Cedar Rapids with Address, Phone number from Yahoo US Local. Includes Edward Jones - Financial Advisor: Jeremy R Clark Reviews, maps & directions to Edward Jones - Financial Advisor: Jeremy R Clark in Cedar Rapids and more from Yahoo US Local",
#       "og:site_name": "Yahoo Local",
#       "business:contact_data:street_address": "3136 Mount Vernon Rd Se",
#       "business:contact_data:locality": "Cedar Rapids",
#       "business:contact_data:region": "IA",
#       "business:contact_data:postal_code": "52403",
#       "business:contact_data:country_name": "United States",
#       "business:contact_data:phone_number": "(319) 363-8111",
#       "business:contact_data:website": "http://www.edwardjones.com/en_US/fa/index.html&CIRN=327854",
#       "place:location:latitude": "41.977201",
#       "place:location:longitude": "-91.621903",
#       "twitter:card": "summary_large_image",
#       "twitter:site": "@YahooLocal",
#       "twitter:title": "Edward Jones - Financial Advisor: Jeremy R Clark",
#       "twitter:image:src": "https://s.yimg.com/tj/locals/d/misc/1.2/local2.png",
#       "twitter:description": "Find Edward Jones - Financial Advisor: Jeremy R Clark in Cedar Rapids with Address, Phone number from Yahoo US Local. Includes Edward Jones - Financial Advisor: Jeremy R Clark Reviews, maps & directions to Edward Jones - Financial Advisor: Jeremy R Clark in Cedar Rapids and more from Yahoo US Local"
#      }
#     ],
#     "breadcrumb": [
#      {
#       "title": "Legal & Financial Services"
#      },
#      {
#       "title": "Investment Services"
#      },
#      {
#       "title": "Investment Banks"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Clark Partington Hart Larry Bond & Stackhouse: Pensacola ...",
#    "htmlTitle": "\u003cb\u003eClark\u003c/b\u003e Partington Hart Larry Bond &amp; Stackhouse: Pensacola \u003cb\u003e...\u003c/b\u003e",
#    "link": "http://www.cphlaw.com/",
#    "displayLink": "www.cphlaw.com",
#    "snippet": "People are our primary asset  Imagine having over 35 ... We are the law firm of \nClark, Partington, Hart, Larry, Bond & Stackhouse. For more than three decades...",
#    "htmlSnippet": "People are our primary \u003cb\u003easset\u003c/b\u003e &middot; Imagine having over 35 ... We are the law firm of \u003cbr\u003e\n\u003cb\u003eClark\u003c/b\u003e, Partington, Hart, Larry, Bond &amp; Stackhouse. For more than three decades&nbsp;...",
#    "cacheId": "bP8e25rB420J",
#    "formattedUrl": "www.cphlaw.com/",
#    "htmlFormattedUrl": "www.cphlaw.com/",
#    "pagemap": {
#     "postaladdress": [
#      {
#       "streetaddress": "One Pensacola Plaza, Suite 800 125 West Romana St. Pensacola, FL 32502",
#       "addresslocality": "Pensacola",
#       "addressregion": "FL",
#       "postalcode": "32502",
#       "telephone": "(850) 434.9200"
#      },
#      {
#       "streetaddress": "4100 Legendary Drive Suite 200 Destin, FL 32541",
#       "addresslocality": "Destin",
#       "addressregion": "FL",
#       "postalcode": "32541",
#       "telephone": "(850) 650.3304"
#      },
#      {
#       "streetaddress": "106 E. College Avenue Suite 600 Tallahassee, FL 32301",
#       "addresslocality": "Tallahassee",
#       "addressregion": "FL",
#       "postalcode": "32301",
#       "telephone": "(850) 597.7483"
#      },
#      {
#       "streetaddress": "1701 East County Highway 30A Suite 201C",
#       "addresslocality": "Santa Rosa Beach",
#       "addressregion": "FL",
#       "postalcode": "32459"
#      },
#      {
#       "streetaddress": "4725 Main Street Suite F-222",
#       "addresslocality": "Orange Beach",
#       "addressregion": "Al",
#       "postalcode": "36561"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Natalie Portman tells Harvard seniors to use inexperience as an asset",
#    "htmlTitle": "Natalie Portman tells Harvard seniors to use inexperience as an \u003cb\u003easset\u003c/b\u003e",
#    "link": "https://www.bostonglobe.com/lifestyle/names/2015/05/27/natalie-portman-tells-harvard-seniors-use-inexperience-asset/GS5LQ3rgc15FEJgLuisYFJ/story.html",
#    "displayLink": "www.bostonglobe.com",
#    "snippet": "May 27, 2015 ... Sam Clark paused to praise  and perhaps poke fun at  the actress's \nimpressive resume. As an aspiring actor myself, I admire your work in...",
#    "htmlSnippet": "May 27, 2015 \u003cb\u003e...\u003c/b\u003e Sam \u003cb\u003eClark\u003c/b\u003e paused to praise  and perhaps poke fun at  the actress&#39;s \u003cbr\u003e\nimpressive resume. As an aspiring actor myself, I admire your work in&nbsp;...",
#    "formattedUrl": "https://www.bostonglobe.com/lifestyle/names/2015/...asset/.../story.html",
#    "htmlFormattedUrl": "https://www.bostonglobe.com/lifestyle/names/2015/...\u003cb\u003easset\u003c/b\u003e/.../story.html",
#    "pagemap": {
#     "cse_image": [
#      {
#       "src": "http://c.o0bg.com/rf/image_585w/Boston/2011-2020/2015/05/27/BostonGlobe.com/Lifestyle/Images/wiggs_Portman_346868.jpg"
#      }
#     ],
#     "cse_thumbnail": [
#      {
#       "width": "248",
#       "height": "203",
#       "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTjkTPqGYMIbAtCZwJlydanztxz_By-xhhvCz1TjiwB4sI4zv8ORfqmH_0D"
#      }
#     ],
#     "postaladdress": [
#      {
#       "addresslocality": "Boston",
#       "addressregion": "MA",
#       "addresscountry": "US"
#      }
#     ],
#     "newsarticle": [
#      {
#       "inlanguage": "en-US",
#       "genre": "news",
#       "articlesection": "Names",
#       "headline": "Natalie Portman offers advice to Harvard seniors",
#       "name": "Mark Shanahan",
#       "datepublished": "2015-05-27 21:56",
#       "articlebody": "Natalie Portman said Wednesday that she was flattered to be invited to speak at Harvards Class Day, but she was also intimidated.The Oscar-winning actress, who graduated from Harvard in..."
#      }
#     ],
#     "geocoordinates": [
#      {
#       "latitude": "42.3600825",
#       "longitude": "-71.05888010000001"
#      }
#     ],
#     "metatags": [
#      {
#       "eomportal-instanceid": "17",
#       "eomportal-id": "498053",
#       "eomportal-loid": "4.0.3080097920",
#       "eomportal-uuid": "354bd428-04ba-11e5-bf99-2b8c49b8f267",
#       "eomportal-lastupdate": "Sun Jul 05 16:57:31 EDT 2015",
#       "og:latitude": "42.3600825",
#       "og:longitude": "-71.05888010000001",
#       "og:city": "Boston",
#       "og:state": "MA",
#       "og:country": "US",
#       "og:type": "article",
#       "og:description": "Natalie Portman tells Harvard seniors to use inexperience as an asset.",
#       "og:title": "Natalie Portman tells Harvard seniors to use inexperience as an asset - The Boston Globe",
#       "og:site_name": "BostonGlobe.com",
#       "fb:admins": "100001044693856",
#       "fb:app_id": "103933749691726",
#       "article:publisher": "https://www.facebook.com/globe",
#       "flashsale": "false",
#       "twitter:account_id": "95431448",
#       "news_keywords": "natalie portman,harvard,class day, Natalie Portman, Will  Ferrell, Sheryl  Sandberg, Andy  Samberg, Amy  Poehler, Christiane  Amanpour,Boston Globe",
#       "og:url": "https://www.bostonglobe.com/lifestyle/names/2015/05/27/natalie-portman-tells-harvard-seniors-use-inexperience-asset/GS5LQ3rgc15FEJgLuisYFJ/story.html",
#       "twitter:card": "summary",
#       "twitter:site": "BostonGlobe",
#       "og:image": "http://c.o0bg.com/rf/image_585w/Boston/2011-2020/2015/05/27/BostonGlobe.com/Lifestyle/Images/wiggs_Portman_346868.jpg",
#       "viewport": "width=device-width, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no"
#      }
#     ],
#     "imageobject": [
#      {
#       "contenturl": "https://c.o0bg.com/rf/image_960w/Boston/2011-2020/2015/05/27/BostonGlobe.com/Lifestyle/Images/wiggs_Portman_346868.jpg",
#       "creator": "Jonathan Wiggs",
#       "description": "Actress Natalie Portman (with Harvard senior Chisom Okpala, right) at Harvards Class Day on Wednesday.",
#       "caption": "Actress Natalie Portman (with Harvard senior Chisom Okpala, right) at Harvards Class Day on Wednesday."
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "St James International | LinkedIn",
#    "htmlTitle": "St James International | LinkedIn",
#    "link": "https://www.linkedin.com/company/st-james-international",
#    "displayLink": "www.linkedin.com",
#    "snippet": "Jeremy Clark: President/CEO ... Caledonian International Associates  NWD \nPrivate Asset Management, a.s.  St. James's Place Wealth Management...",
#    "htmlSnippet": "\u003cb\u003eJeremy Clark\u003c/b\u003e: President/CEO ... Caledonian International Associates &middot; NWD \u003cbr\u003e\nPrivate \u003cb\u003eAsset\u003c/b\u003e Management, a.s. &middot; St. James&#39;s Place Wealth Management&nbsp;...",
#    "cacheId": "vXreo6l1AGAJ",
#    "formattedUrl": "https://www.linkedin.com/company/st-james-international",
#    "htmlFormattedUrl": "https://www.linkedin.com/company/st-james-international",
#    "pagemap": {
#     "cse_image": [
#      {
#       "src": "https://media.licdn.com/mpr/mpr/shrink_200_100/p/2/005/0b3/0ca/24fb505.png"
#      }
#     ],
#     "cse_thumbnail": [
#      {
#       "width": "160",
#       "height": "80",
#       "src": "https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQtYFN0H-603U5GvxxPh9FFjrEaSNqmYqLYgw_bRTH64XFt65LK75gWdvE"
#      }
#     ],
#     "postaladdress": [
#      {
#       "streetaddress": "Local 8 Alto, Edif. Barclays",
#       "addresslocality": "Marbella,",
#       "addressregion": "Malaga",
#       "postalcode": "29670",
#       "addresscountry": "Spain"
#      }
#     ],
#     "metatags": [
#      {
#       "globaltrackingurl": "//www.linkedin.com/mob/tracking",
#       "globaltrackingappname": "biz",
#       "globaltrackingappid": "webTracking",
#       "lnkd-track-json-lib": "https://static.licdn.com/scds/concat/common/js?v=build-2000_8_48563-prod&f=lib%2Fjson%2Fjson2&f=lib%2Ferror-tracking%2F1.0.0%2Fshared%2Fxhr.min&fc=2",
#       "treeid": "J5ksgtgP7BPgPD/QFysAAA==",
#       "appname": "biz",
#       "pageimpressionid": "4ea91eb0-903d-4161-ab07-3f6e2e8e0f19",
#       "pagekey": "biz-overview-company-public",
#       "analyticsurl": "/analytics/noauthtracker",
#       "msapplication-tileimage": "https://static.licdn.com/scds/common/u/images/logos/linkedin/logo-in-win8-tile-144_v1.png",
#       "msapplication-tilecolor": "#0077B5",
#       "application-name": "LinkedIn",
#       "remote-nav-init-marker": "true",
#       "og:image": "https://media.licdn.com/mpr/mpr/shrink_200_100/p/2/005/0b3/0ca/24fb505.png",
#       "og:description": "St James International is an established firm of Independent Investment Brokers providing specialist financial advice for international investors of all nations, worldwide. As Independent Offshore Investment Brokers we have access to the world's top Fund Management groups and hence we are able to offer an extensive and wide range of investment products. Our independence enables us to put into practice our belief that personal service, attention to detail and friendliness are not incompatible with professionalism and success in an increasingly complex financial environment.    St James International is a firm of Independent Offshore Investment Brokers and as such are not authorised to provide investment advice in the United Kingdom and only for persons resident outside the UK and the USA.",
#       "og:type": "article",
#       "og:title": "St James International",
#       "og:url": "http://www.linkedin.com/company/st-james-international"
#      }
#     ],
#     "corporation": [
#      {
#       "name": "St James International"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Lessons From Huguette Clark's Estate | Philadelphia PA Estate ...",
#    "htmlTitle": "Lessons From Huguette \u003cb\u003eClark&#39;s\u003c/b\u003e Estate | Philadelphia PA Estate \u003cb\u003e...\u003c/b\u003e",
#    "link": "http://jawatlaw.com/lawyer/2013/06/20/Estate-Planning/Lessons-From-Huguette-Clarks-Estate_bl8536.htm",
#    "displayLink": "jawatlaw.com",
#    "snippet": "Jun 20, 2013 ... Lessons From Huguette Clark's Estate. Huguette Clark passed away in 2011 at \nthe age of 104, leaving in her will $300 million of ... Asset Protection .... The Law \nOffices of Jeremy A. Wechsler assist clients with Estate Planning...",
#    "htmlSnippet": "Jun 20, 2013 \u003cb\u003e...\u003c/b\u003e Lessons From Huguette \u003cb\u003eClark&#39;s\u003c/b\u003e Estate. Huguette \u003cb\u003eClark\u003c/b\u003e passed away in 2011 at \u003cbr\u003e\nthe age of 104, leaving in her will $300 million of ... \u003cb\u003eAsset\u003c/b\u003e Protection .... The Law \u003cbr\u003e\nOffices of \u003cb\u003eJeremy\u003c/b\u003e A. Wechsler assist clients with Estate Planning&nbsp;...",
#    "cacheId": "_KS0vBA4-7kJ",
#    "formattedUrl": "jawatlaw.com/.../Lessons-From-Huguette-Clarks-Estate_bl8536.htm",
#    "htmlFormattedUrl": "jawatlaw.com/.../Lessons-From-Huguette-\u003cb\u003eClarks\u003c/b\u003e-Estate_bl8536.htm",
#    "pagemap": {
#     "postaladdress": [
#      {
#       "streetaddress": "2300 Computer Avenue, Suite J-54",
#       "addresslocality": "Willow Grove",
#       "addressregion": "PA",
#       "postalcode": "19090"
#      }
#     ],
#     "attorney": [
#      {
#       "legalname": "The Law Offices of Jeremy A. Wechsler",
#       "telephone": "Phone: 215-706-0200"
#      }
#     ],
#     "metatags": [
#      {
#       "og:title": "Lessons From Huguette Clark's Estate | Philadelphia PA Estate Planning Blog",
#       "og:type": "website",
#       "og:url": "http://jawatlaw.com/lawyer/2013/06/20/Estate-Planning/Lessons-From-Huguette-Clarks-Estate_bl8536.htm",
#       "og:site_name": "jawatlaw.com"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Our People | 360 Finance",
#    "htmlTitle": "Our People | 360 Finance",
#    "link": "https://www.360finance.com.au/our-people/",
#    "displayLink": "www.360finance.com.au",
#    "snippet": "Adam Clark : Finance & Insurance Manager. Adam Clark. Finance ..... If your \nlooking for any type of asset finance Simon is more than happy to help. Simon \nwas...",
#    "htmlSnippet": "Adam \u003cb\u003eClark\u003c/b\u003e : Finance &amp; Insurance Manager. Adam \u003cb\u003eClark\u003c/b\u003e. Finance ..... If your \u003cbr\u003e\nlooking for any type of \u003cb\u003easset\u003c/b\u003e finance Simon is more than happy to help. Simon \u003cbr\u003e\nwas&nbsp;...",
#    "cacheId": "Kv8XM0Z5P9UJ",
#    "formattedUrl": "https://www.360finance.com.au/our-people/",
#    "htmlFormattedUrl": "https://www.360finance.com.au/our-people/",
#    "pagemap": {
#     "cse_image": [
#      {
#       "src": "https://www.360finance.com.au/media/360_our_people.jpg"
#      }
#     ],
#     "person": [
#      {
#       "name": "Reece & Debbie"
#      },
#      {
#       "name": "Andreas A"
#      },
#      {
#       "name": "D & S Johnson"
#      },
#      {
#       "name": "Prokopios T"
#      },
#      {
#       "name": "D & G McPhee"
#      },
#      {
#       "name": "P Alvis"
#      },
#      {
#       "name": "Heidi R"
#      },
#      {
#       "name": "L Gray"
#      },
#      {
#       "name": "B McDonald"
#      },
#      {
#       "name": "A McMahon"
#      },
#      {
#       "name": "Kimberly A"
#      },
#      {
#       "name": "Peter J S"
#      },
#      {
#       "name": "I & A Goodwin"
#      },
#      {
#       "name": "P Chapman"
#      },
#      {
#       "name": "Lynne & Ferdinand K"
#      },
#      {
#       "name": "S Dubois"
#      },
#      {
#       "name": "Aysha T"
#      },
#      {
#       "name": "Glen M"
#      },
#      {
#       "name": "CJ & SJ Cull Pty Ltd"
#      },
#      {
#       "name": "Lucas and Gemma W"
#      },
#      {
#       "name": "Kimberlee C"
#      },
#      {
#       "name": "Debra V M"
#      },
#      {
#       "name": "Luke M"
#      },
#      {
#       "name": "D Kugis"
#      },
#      {
#       "name": "K & D Briggs"
#      }
#     ],
#     "hreview": [
#      {
#       "summary": "I was happy with the whole experience. Nothing was any problem from 360 Finance. I only rang 360 Finance to ask a question about finance and within an ho",
#       "dtreviewed": "2013-08-18",
#       "description": "I was happy with the whole experience. Nothing was any problem from 360 Finance. I only rang 360 Finance to ask a question about finance and within an hour it was all done and approved. Matt..."
#      },
#      {
#       "summary": "Richard was all over the whole process and stayed in touch. Excellent service experience!",
#       "dtreviewed": "2014-03-31",
#       "description": "Richard was all over the whole process and stayed in touch. Excellent service experience!"
#      },
#      {
#       "summary": "I was extremely impressed! Tim's speed and product knowledge was outstanding. He really went the extra mile to ensure I got the best deal possible. Flawle",
#       "dtreviewed": "2014-03-18",
#       "description": "I was extremely impressed! Tim's speed and product knowledge was outstanding. He really went the extra mile to ensure I got the best deal possible. Flawless service provided by a true professional."
#      },
#      {
#       "summary": "Adam went to extreme measures to meet our needs and he could not be improved as he is outstanding, professional and a remarkable person that we have actuall",
#       "dtreviewed": "2014-03-19",
#       "description": "Adam went to extreme measures to meet our needs and he could not be improved as he is outstanding, professional and a remarkable person that we have actually dealt with before."
#      },
#      {
#       "summary": "Ruby was very helpful and answered all of my questions. Fast approval too!",
#       "dtreviewed": "2014-03-19",
#       "description": "Ruby was very helpful and answered all of my questions. Fast approval too!"
#      },
#      {
#       "summary": "Damien was very quick to respond, even in his absence someone else took over for a day. A very friendly guy, easy to deal with and very professional.Very g",
#       "dtreviewed": "2014-02-20",
#       "description": "Damien was very quick to respond, even in his absence someone else took over for a day. A very friendly guy, easy to deal with and very professional.Very good experience, would recommend to anyone."
#      },
#      {
#       "summary": "Gerald was very friendly and honest about all the details. I am very pleased with your company and will be recommending Gerald to friends.",
#       "dtreviewed": "2014-03-22",
#       "description": "Gerald was very friendly and honest about all the details. I am very pleased with your company and will be recommending Gerald to friends."
#      },
#      {
#       "summary": "From the moment I first rang to the very end of the process. Natika was absolutely sensational. She constantly kept me updated with the progress and alway",
#       "dtreviewed": "2014-06-17",
#       "description": "From the moment I first rang to the very end of the process. Natika was absolutely sensational. She constantly kept me updated with the progress and always offered a guaranteed personalised..."
#      },
#      {
#       "summary": "Communication and knowledge of subject matter was excellent! Matt's service has been extremely thorough and exemplary. Outstanding!",
#       "dtreviewed": "2014-03-19",
#       "description": "Communication and knowledge of subject matter was excellent! Matt's service has been extremely thorough and exemplary. Outstanding!"
#      },
#      {
#       "summary": "Thanks again for all your help. Would highly recommend 360 finance  specifically yourself to friends.",
#       "dtreviewed": "2014-04-14",
#       "description": "Thanks again for all your help. Would highly recommend 360 finance  specifically yourself to friends."
#      },
#      {
#       "summary": "I was really impressed with Les going the extra mile.",
#       "dtreviewed": "2014-03-06",
#       "description": "I was really impressed with Les going the extra mile."
#      },
#      {
#       "summary": "Chris has been exceptional! Quick, efficient service.",
#       "dtreviewed": "2014-03-24",
#       "description": "Chris has been exceptional! Quick, efficient service."
#      },
#      {
#       "summary": "Rob always returned calls and emails in a timely manner and kept us well informed with what was going on.",
#       "dtreviewed": "2014-03-12",
#       "description": "Rob always returned calls and emails in a timely manner and kept us well informed with what was going on."
#      },
#      {
#       "summary": "The constant contact with what was happening and where it was all at. Very pleased...",
#       "dtreviewed": "2014-02-21",
#       "description": "The constant contact with what was happening and where it was all at. Very pleased..."
#      },
#      {
#       "summary": "Phil was very professional and extremely helpful during the whole process. He followed up and kept us informed all the way.",
#       "dtreviewed": "2014-03-16",
#       "description": "Phil was very professional and extremely helpful during the whole process. He followed up and kept us informed all the way."
#      },
#      {
#       "summary": "Gary provided fantastic customer service, and made the whole process smooth and easy. Gary is definitely an asset to your company.",
#       "dtreviewed": "2014-04-02",
#       "description": "Gary provided fantastic customer service, and made the whole process smooth and easy. Gary is definitely an asset to your company."
#      },
#      {
#       "summary": "Very impressed with my finance consultant services. Great customer service, prompt responses.",
#       "dtreviewed": "2014-03-10",
#       "description": "Very impressed with my finance consultant services. Great customer service, prompt responses."
#      },
#      {
#       "summary": "Simon was always quick to keep me updated on progress. Great communication, Cheers!",
#       "dtreviewed": "2014-03-19",
#       "description": "Simon was always quick to keep me updated on progress. Great communication, Cheers!"
#      },
#      {
#       "summary": "Corey was very helpful, right from the first contact.",
#       "dtreviewed": "2014-03-19",
#       "description": "Corey was very helpful, right from the first contact."
#      },
#      {
#       "summary": "Honestly, the service was fantastic! No criticism whatsoever. Thanks Dan for all your help. Awesome service, Dan even came to our house after hours, whic",
#       "dtreviewed": "2015-01-19",
#       "description": "Honestly, the service was fantastic! No criticism whatsoever. Thanks Dan for all your help. Awesome service, Dan even came to our house after hours, which was great. We will recommend 360 to..."
#      },
#      {
#       "summary": "The service was fantasic! Mark went above and beyond and made the process to purchasing my car so stress free and easy.",
#       "dtreviewed": "2014-12-22",
#       "description": "The service was fantasic! Mark went above and beyond and made the process to purchasing my car so stress free and easy."
#      },
#      {
#       "summary": "360 Finance are awesome. Definitely Highly recommend.",
#       "dtreviewed": "2014-12-22",
#       "description": "360 Finance are awesome. Definitely Highly recommend."
#      },
#      {
#       "summary": "Nothing was too much trouble for Patty and he was always down for a laugh!! I love the fact that the company work outside regular office hours as I was lock",
#       "dtreviewed": "2014-12-22",
#       "description": "Nothing was too much trouble for Patty and he was always down for a laugh!! I love the fact that the company work outside regular office hours as I was locked at work until 5pm everyday, and..."
#      },
#      {
#       "summary": "The service from Jason couldn't get any more professional. My husband and I will not hesitate to call him in regards to any queries we may have. Communica",
#       "dtreviewed": "2015-04-15",
#       "description": "The service from Jason couldn't get any more professional. My husband and I will not hesitate to call him in regards to any queries we may have. Communication via phone, emails and especially..."
#      },
#      {
#       "summary": "Jerry provided detailed information and took the time to explain things to me as a first timer taking out a loan. He was very friendly and professional. V",
#       "dtreviewed": "2015-06-01",
#       "description": "Jerry provided detailed information and took the time to explain things to me as a first timer taking out a loan. He was very friendly and professional. Very helpful and prompt with email responses."
#      }
#     ],
#     "aggregaterating": [
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      },
#      {
#       "reviewcount": "0",
#       "ratingcount": "0"
#      }
#     ],
#     "postaladdress": [
#      {
#       "streetaddress": "1032 Beaudesert Road, Coopers Plains QLD 4108",
#       "postofficeboxnumber": "3632",
#       "addresslocality": "South Brisbane",
#       "addressregion": "QLD",
#       "postalcode": "4101",
#       "telephone": "1300 361 360",
#       "faxnumber": "07 3336 3300",
#       "email": "info@360finance.com.au"
#      }
#     ],
#     "webpage": [
#      {
#       "headline": "Our People"
#      }
#     ],
#     "metatags": [
#      {
#       "viewport": "width=device-width, initial-scale=1.0",
#       "msapplication-tilecolor": "#ea2f2c",
#       "msapplication-tileimage": "https://www.360finance.com.au/wp-content/themes/360finance/library/images/win8-tile-icon.png",
#       "theme-color": "#ea2f2c",
#       "fb:app_id": "1554084711526647",
#       "fb:admins": "760245246",
#       "og:url": "https://www.360finance.com.au/our-people/",
#       "og:site_name": "360 Finance Pty Ltd",
#       "og:title": "Our People",
#       "og:description": "Making finance quick and easy",
#       "og:type": "website",
#       "og:image": "https://www.360finance.com.au/media/360_our_people.jpg"
#      }
#     ],
#     "review": [
#      {
#       "reviewer": "Reece & Debbie",
#       "reviewdate": "2013-08-18"
#      },
#      {
#       "reviewbody": "I was happy with the whole experience. Nothing was any problem from 360 Finance. I only rang 360 Finance to ask a question about finance and within an hour it was all done and approved. Matt...",
#       "datepublished": "2013-08-18",
#       "datemodified": "2014-03-26",
#       "url": "https://www.360finance.com.au/testimonial/reece-debbie/",
#       "name": "I was happy with the whole experience. Nothing was any problem from 360 Finance. I only rang 360 Finance to ask a question about finance and within an ho"
#      },
#      {
#       "reviewbody": "Richard was all over the whole process and stayed in touch. Excellent service experience!",
#       "datepublished": "2014-03-31",
#       "datemodified": "2014-03-31",
#       "url": "https://www.360finance.com.au/testimonial/andreas/",
#       "name": "Richard was all over the whole process and stayed in touch. Excellent service experience!"
#      },
#      {
#       "reviewbody": "I was extremely impressed! Tim's speed and product knowledge was outstanding. He really went the extra mile to ensure I got the best deal possible. Flawless service provided by a true professional.",
#       "datepublished": "2014-03-18",
#       "datemodified": "2014-03-26",
#       "url": "https://www.360finance.com.au/testimonial/d-s-johnson/",
#       "name": "I was extremely impressed! Tim's speed and product knowledge was outstanding. He really went the extra mile to ensure I got the best deal possible. Flawle"
#      },
#      {
#       "reviewbody": "Adam went to extreme measures to meet our needs and he could not be improved as he is outstanding, professional and a remarkable person that we have actually dealt with before.",
#       "datepublished": "2014-03-19",
#       "datemodified": "2014-03-21",
#       "url": "https://www.360finance.com.au/testimonial/prokopios-t/",
#       "name": "Adam went to extreme measures to meet our needs and he could not be improved as he is outstanding, professional and a remarkable person that we have actuall"
#      },
#      {
#       "reviewbody": "Ruby was very helpful and answered all of my questions. Fast approval too!",
#       "datepublished": "2014-03-19",
#       "datemodified": "2014-03-21",
#       "url": "https://www.360finance.com.au/testimonial/d-g-mcphee/",
#       "name": "Ruby was very helpful and answered all of my questions. Fast approval too!"
#      },
#      {
#       "reviewbody": "Damien was very quick to respond, even in his absence someone else took over for a day. A very friendly guy, easy to deal with and very professional.Very good experience, would recommend to anyone.",
#       "datepublished": "2014-02-20",
#       "datemodified": "2014-03-26",
#       "url": "https://www.360finance.com.au/testimonial/p-alvis/",
#       "name": "Damien was very quick to respond, even in his absence someone else took over for a day. A very friendly guy, easy to deal with and very professional.Very g"
#      },
#      {
#       "reviewbody": "Gerald was very friendly and honest about all the details. I am very pleased with your company and will be recommending Gerald to friends.",
#       "datepublished": "2014-03-22",
#       "datemodified": "2014-03-26",
#       "url": "https://www.360finance.com.au/testimonial/heidi-r/",
#       "name": "Gerald was very friendly and honest about all the details. I am very pleased with your company and will be recommending Gerald to friends."
#      },
#      {
#       "reviewbody": "From the moment I first rang to the very end of the process. Natika was absolutely sensational. She constantly kept me updated with the progress and always offered a guaranteed personalised...",
#       "datepublished": "2014-06-17",
#       "datemodified": "2014-06-17",
#       "url": "https://www.360finance.com.au/testimonial/l-gray/",
#       "name": "From the moment I first rang to the very end of the process. Natika was absolutely sensational. She constantly kept me updated with the progress and alway"
#      },
#      {
#       "reviewbody": "Communication and knowledge of subject matter was excellent! Matt's service has been extremely thorough and exemplary. Outstanding!",
#       "datepublished": "2014-03-19",
#       "datemodified": "2014-03-19",
#       "url": "https://www.360finance.com.au/testimonial/b-mcdonald/",
#       "name": "Communication and knowledge of subject matter was excellent! Matt's service has been extremely thorough and exemplary. Outstanding!"
#      },
#      {
#       "reviewbody": "Thanks again for all your help. Would highly recommend 360 finance  specifically yourself to friends.",
#       "datepublished": "2014-04-14",
#       "datemodified": "2014-04-14",
#       "url": "https://www.360finance.com.au/testimonial/mcmahon/",
#       "name": "Thanks again for all your help. Would highly recommend 360 finance  specifically yourself to friends."
#      },
#      {
#       "reviewbody": "I was really impressed with Les going the extra mile.",
#       "datepublished": "2014-03-06",
#       "datemodified": "2014-03-26",
#       "url": "https://www.360finance.com.au/testimonial/kimberly/",
#       "name": "I was really impressed with Les going the extra mile."
#      },
#      {
#       "reviewbody": "Chris has been exceptional! Quick, efficient service.",
#       "datepublished": "2014-03-24",
#       "datemodified": "2014-03-24",
#       "url": "https://www.360finance.com.au/testimonial/peter-j-s/",
#       "name": "Chris has been exceptional! Quick, efficient service."
#      },
#      {
#       "reviewbody": "Rob always returned calls and emails in a timely manner and kept us well informed with what was going on.",
#       "datepublished": "2014-03-12",
#       "datemodified": "2014-03-12",
#       "url": "https://www.360finance.com.au/testimonial/goodwin/",
#       "name": "Rob always returned calls and emails in a timely manner and kept us well informed with what was going on."
#      },
#      {
#       "reviewbody": "The constant contact with what was happening and where it was all at. Very pleased...",
#       "datepublished": "2014-02-21",
#       "datemodified": "2014-02-26",
#       "url": "https://www.360finance.com.au/testimonial/p-chapman/",
#       "name": "The constant contact with what was happening and where it was all at. Very pleased..."
#      },
#      {
#       "reviewbody": "Phil was very professional and extremely helpful during the whole process. He followed up and kept us informed all the way.",
#       "datepublished": "2014-03-16",
#       "datemodified": "2014-03-26",
#       "url": "https://www.360finance.com.au/testimonial/lynne-ferdinand-k/",
#       "name": "Phil was very professional and extremely helpful during the whole process. He followed up and kept us informed all the way."
#      },
#      {
#       "reviewbody": "Gary provided fantastic customer service, and made the whole process smooth and easy. Gary is definitely an asset to your company.",
#       "datepublished": "2014-04-02",
#       "datemodified": "2014-04-02",
#       "url": "https://www.360finance.com.au/testimonial/s-dubois/",
#       "name": "Gary provided fantastic customer service, and made the whole process smooth and easy. Gary is definitely an asset to your company."
#      },
#      {
#       "reviewbody": "Very impressed with my finance consultant services. Great customer service, prompt responses.",
#       "datepublished": "2014-03-10",
#       "datemodified": "2014-03-26",
#       "url": "https://www.360finance.com.au/testimonial/aysha-t/",
#       "name": "Very impressed with my finance consultant services. Great customer service, prompt responses."
#      },
#      {
#       "reviewbody": "Simon was always quick to keep me updated on progress. Great communication, Cheers!",
#       "datepublished": "2014-03-19",
#       "datemodified": "2014-03-19",
#       "url": "https://www.360finance.com.au/testimonial/glen-m/",
#       "name": "Simon was always quick to keep me updated on progress. Great communication, Cheers!"
#      },
#      {
#       "reviewbody": "Corey was very helpful, right from the first contact.",
#       "datepublished": "2014-03-19",
#       "datemodified": "2014-03-21",
#       "url": "https://www.360finance.com.au/testimonial/cj-sj-cull-pty-ltd/",
#       "name": "Corey was very helpful, right from the first contact."
#      },
#      {
#       "reviewbody": "Honestly, the service was fantastic! No criticism whatsoever. Thanks Dan for all your help. Awesome service, Dan even came to our house after hours, which was great. We will recommend 360 to...",
#       "datepublished": "2015-01-19",
#       "datemodified": "2015-01-19",
#       "url": "https://www.360finance.com.au/testimonial/lucas-gemma-w/",
#       "name": "Honestly, the service was fantastic! No criticism whatsoever. Thanks Dan for all your help. Awesome service, Dan even came to our house after hours, whic"
#      },
#      {
#       "reviewbody": "The service was fantasic! Mark went above and beyond and made the process to purchasing my car so stress free and easy.",
#       "datepublished": "2014-12-22",
#       "datemodified": "2014-12-22",
#       "url": "https://www.360finance.com.au/testimonial/kimberlee-c/",
#       "name": "The service was fantasic! Mark went above and beyond and made the process to purchasing my car so stress free and easy."
#      },
#      {
#       "reviewbody": "360 Finance are awesome. Definitely Highly recommend.",
#       "datepublished": "2014-12-22",
#       "datemodified": "2014-12-22",
#       "url": "https://www.360finance.com.au/testimonial/debra-v-m/",
#       "name": "360 Finance are awesome. Definitely Highly recommend."
#      },
#      {
#       "reviewbody": "Nothing was too much trouble for Patty and he was always down for a laugh!! I love the fact that the company work outside regular office hours as I was locked at work until 5pm everyday, and...",
#       "datepublished": "2014-12-22",
#       "datemodified": "2014-12-22",
#       "url": "https://www.360finance.com.au/testimonial/luke-m/",
#       "name": "Nothing was too much trouble for Patty and he was always down for a laugh!! I love the fact that the company work outside regular office hours as I was lock"
#      },
#      {
#       "reviewbody": "The service from Jason couldn't get any more professional. My husband and I will not hesitate to call him in regards to any queries we may have. Communication via phone, emails and especially...",
#       "datepublished": "2015-04-15",
#       "datemodified": "2015-06-01",
#       "url": "https://www.360finance.com.au/testimonial/d-kugis/",
#       "name": "The service from Jason couldn't get any more professional. My husband and I will not hesitate to call him in regards to any queries we may have. Communica"
#      },
#      {
#       "reviewbody": "Jerry provided detailed information and took the time to explain things to me as a first timer taking out a loan. He was very friendly and professional. Very helpful and prompt with email responses.",
#       "datepublished": "2015-06-01",
#       "datemodified": "2015-06-01",
#       "url": "https://www.360finance.com.au/testimonial/k-d-briggs/",
#       "name": "Jerry provided detailed information and took the time to explain things to me as a first timer taking out a loan. He was very friendly and professional. V"
#      }
#     ],
#     "thing": [
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      },
#      {
#       "name": "360 Finance",
#       "url": "https://www.360finance.com.au"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Peter Littlefield | Turcan Connell",
#    "htmlTitle": "Peter Littlefield | Turcan Connell",
#    "link": "http://www.turcanconnell.com/people/partners-principal/partners/peter-littlefield",
#    "displayLink": "www.turcanconnell.com",
#    "snippet": "Peter works principally in the areas of contentious probate, succession planning, \ntrust law, will drafting, tax planning, asset protection, executry administration...",
#    "htmlSnippet": "Peter works principally in the areas of contentious probate, succession planning, \u003cbr\u003e\ntrust law, will drafting, tax planning, \u003cb\u003easset\u003c/b\u003e protection, executry administration&nbsp;...",
#    "cacheId": "AfJPBQ_Eer4J",
#    "formattedUrl": "www.turcanconnell.com/people/.../peter-littlefield",
#    "htmlFormattedUrl": "www.turcanconnell.com/people/.../peter-littlefield",
#    "pagemap": {
#     "cse_image": [
#      {
#       "src": "http://www.turcanconnell.com/Images.ashx?i=/media/425207/peter-littlefield_web.jpg&w=&h="
#      }
#     ],
#     "cse_thumbnail": [
#      {
#       "width": "116",
#       "height": "134",
#       "src": "https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcSxuCgkuWjVlhjo2zu-HALJr57T72q7_kCp6mZ8P1pINGKWAR6-2wI7_g"
#      }
#     ],
#     "postaladdress": [
#      {
#       "url": "Edinburgh",
#       "streetaddress": "Princes Exchange, 1 Earl Grey Street,",
#       "addresslocality": "Edinburgh,",
#       "postalcode": "EH3 9EE"
#      }
#     ],
#     "metatags": [
#      {
#       "og:title": "Turcan Connell",
#       "og:type": "website",
#       "og:url": "http://www.turcanconnell.com/people/partners-principal/partners/peter-littlefield",
#       "og:image": "/media/717001/tc-icon.png",
#       "og:description": "Profile of Peter Littlefield - Partner: Wills, Estate Planning and Succession",
#       "twitter:card": "summary",
#       "twitter:site": "@TurcanConnell",
#       "twitter:title": "Turcan Connell",
#       "twitter:description": "Profile of Peter Littlefield - Partner: Wills, Estate Planning and Succession",
#       "twitter:image": "/media/717001/tc-icon.png",
#       "viewport": "width=device-width, initial-scale=1, maximum-scale=1",
#       "apple-mobile-web-app-capable": "yes",
#       "apple-mobile-web-app-status-bar-style": "black-translucent"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Retirement Asset Protection Trusts for IRA's | Philadelphia PA Estate ...",
#    "htmlTitle": "Retirement \u003cb\u003eAsset\u003c/b\u003e Protection Trusts for IRA&#39;s | Philadelphia PA Estate \u003cb\u003e...\u003c/b\u003e",
#    "link": "http://jawatlaw.com/lawyer/2011/02/07/Estate-Planning/Retirement-Asset-Protection-Trusts-for-IRAs_bl1798.htm",
#    "displayLink": "jawatlaw.com",
#    "snippet": "Feb 7, 2011 ... The most substantial asset in someone's portfolio is often their IRA. An IRA (\nIndividual Retirement Arrangement) is a tax-deferment or savings...",
#    "htmlSnippet": "Feb 7, 2011 \u003cb\u003e...\u003c/b\u003e The most substantial \u003cb\u003easset\u003c/b\u003e in someone&#39;s portfolio is often their IRA. An IRA (\u003cbr\u003e\nIndividual Retirement Arrangement) is a tax-deferment or savings&nbsp;...",
#    "cacheId": "rkav-Wz02QkJ",
#    "formattedUrl": "jawatlaw.com/.../Retirement-Asset-Protection-Trusts-for-IRAs_bl1798.htm",
#    "htmlFormattedUrl": "jawatlaw.com/.../Retirement-\u003cb\u003eAsset\u003c/b\u003e-Protection-Trusts-for-IRAs_bl1798.htm",
#    "pagemap": {
#     "postaladdress": [
#      {
#       "streetaddress": "2300 Computer Avenue, Suite J-54",
#       "addresslocality": "Willow Grove",
#       "addressregion": "PA",
#       "postalcode": "19090"
#      }
#     ],
#     "attorney": [
#      {
#       "legalname": "The Law Offices of Jeremy A. Wechsler",
#       "telephone": "Phone: 215-706-0200"
#      }
#     ],
#     "metatags": [
#      {
#       "og:title": "Retirement Asset Protection Trusts for IRA's | Philadelphia PA Estate Planning Blog",
#       "og:type": "website",
#       "og:url": "http://jawatlaw.com/lawyer/2011/02/07/Estate-Planning/Retirement-Asset-Protection-Trusts-for-IRAs_bl1798.htm",
#       "og:site_name": "jawatlaw.com"
#      }
#     ]
#    }
#   }
#  ]
# }

# %% [markdown]
# tangent: [Natalie Portman tells Harvard seniors to use inexperience as an asset - The Boston Globe](https://www.bostonglobe.com/lifestyle/names/2015/05/27/natalie-portman-tells-harvard-seniors-use-inexperience-asset/GS5LQ3rgc15FEJgLuisYFJ/story.htm)

# %% [markdown]
# **Reviewing the result with search hits**
#
# Here we can see some similarities as well. It seems like we get into trouble when trying to
# assess the fields within the 'pagemap'. It seems as though the 'snippet' field may be sufficient
# for our needs.
#
# This information seems to be sufficient for creating the next version of the parser. We have
# been able to indentify fields that occur in each result. We have also found fields that occur
# in each search hit.
#
# At this stage, parsing the 'pagemap' seems to be unecessary.

# %% [markdown]
# ## Building a better document converter

# %% [markdown]
# ## Results from Elasticsearch document conversion

# %%
# prepare all documents for bulk upload into elasticsearch
actions = prepare_all_documents(results, esformat, read_csv(filepath, QUERY_LIMIT))

# %%
# it's pretty clear from steping through the documents that
# there are some issues with the parser. The first version
# definitely worked better than nothing but we are going to
# need to make some changes.

actions[47]['_source']
# Out:
# {'account_holder': 'Walter Broughton',
#  'account_number': u'11111417',
#  u'searchInformation': [u'formattedSearchTime',
#   u'formattedTotalResults',
#   u'totalResults',
#   u'searchTime']}
