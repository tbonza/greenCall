# %% [markdown]
# # Elasticsearch Document Conversion
#
# The Elasticsearch Document Conversion from our Search API results appears to be a pain point.
# This notebook is meant to serve as root cause analysis of the issue

# %% [markdown]
# ## Settings Variables

# %%
# Maximum number of query items to request from API
QUERY_LIMIT = 20

# Maximum number or requests deferred
MAX_RUN = 20

# This many seconds will expire between requests sent
RATE_LIMIT = 1

# Path to original excel file, converted to CSV
filepath = 'examples/finance_demo.csv'

# Path to converted file to be used for API requests
outpath = 'examples/ipython_demo.json'

# results returned from the API via the networking engine
resultspath = 'results.json'

# Specify a document template for Elasticsearch
esformat = {
            "_index": "ipythonsearch",
            "_type": "website",
            "_id": None,
            "_source": ""
        }

# %% [markdown]
# ## Reading JSON from Search API Results

# %%
import itertools
import string
import json
from elasticsearch import Elasticsearch,helpers

from greencall.utils.loadelastic import read_json, prepare_all_documents
from greencall.csvclean.inputCsv import read_csv

# Connect to Elasticsearch
es = Elasticsearch()

# Read results from the Search API
results = read_json(resultspath)

# Take the length of the results as a sanity check
len(results)
# Out:
# 5

# %% [markdown]
# ## Reviewing Results from the Google Search API

# %%
# take a look at the first document
import codecs

print("key:\n {}\n".format(results.keys()[0]))
print("result:\n {}".format(codecs.encode(results[results.keys()[0]],'ascii','ignore')))
# Out:
# key:
#  11111143
#
# result:
#  {
#  "kind": "customsearch#search",
#  "url": {
#   "type": "application/json",
#   "template": "https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&cref={cref?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json"
#  },
#  "queries": {
#   "nextPage": [
#    {
#     "title": "Google Custom Search - Kelley Mote",
#     "totalResults": "426",
#     "searchTerms": "Kelley Mote",
#     "count": 10,
#     "startIndex": 11,
#     "language": "lang_en",
#     "inputEncoding": "utf8",
#     "outputEncoding": "utf8",
#     "safe": "off",
#     "cx": "003891126258438650518:fcb7zxrqavu",
#     "filter": "1",
#     "exactTerms": "asset",
#     "dateRestrict": "'2012'"
#    }
#   ],
#   "request": [
#    {
#     "title": "Google Custom Search - Kelley Mote",
#     "totalResults": "426",
#     "searchTerms": "Kelley Mote",
#     "count": 10,
#     "startIndex": 1,
#     "language": "lang_en",
#     "inputEncoding": "utf8",
#     "outputEncoding": "utf8",
#     "safe": "off",
#     "cx": "003891126258438650518:fcb7zxrqavu",
#     "filter": "1",
#     "exactTerms": "asset",
#     "dateRestrict": "'2012'"
#    }
#   ]
#  },
#  "context": {
#   "title": "greencall"
#  },
#  "searchInformation": {
#   "searchTime": 0.710357,
#   "formattedSearchTime": "0.71",
#   "totalResults": "426",
#   "formattedTotalResults": "426"
#  },
#  "items": [
#   {
#    "kind": "customsearch#result",
#    "title": "Honda Village - Auto Repair - Newton Corner, MA - Reviews ...",
#    "htmlTitle": "Honda Village - Auto Repair - Newton Corner, MA - Reviews \u003cb\u003e...\u003c/b\u003e",
#    "link": "http://www.yelp.com/biz/honda-village-newton-corner",
#    "displayLink": "www.yelp.com",
#    "snippet": "Find Out More About Our Trade Up Special! .... If there were more Jims in the car \nsales world, I think the public would have a much higher opinion of car...",
#    "htmlSnippet": "Find Out \u003cb\u003eMore\u003c/b\u003e About Our Trade Up Special! .... If there were \u003cb\u003emore\u003c/b\u003e Jims in the car \u003cbr\u003e\nsales world, I think the public would have a much higher opinion of car&nbsp;...",
#    "cacheId": "HW1sGDhoFY8J",
#    "formattedUrl": "www.yelp.com/biz/honda-village-newton-corner",
#    "htmlFormattedUrl": "www.yelp.com/biz/honda-village-newton-corner",
#    "pagemap": {
#     "cse_image": [
#      {
#       "src": "http://s3-media2.fl.yelpcdn.com/bphoto/ciCFr6ZIplthauOv8MSNBg/o.jpg"
#      }
#     ],
#     "cse_thumbnail": [
#      {
#       "width": "340",
#       "height": "148",
#       "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcReBXReGrBRG1MQ3OdLOpTia6sclgN6Nloba2Rh4yPOBbAGOS5pAzUz4YQ"
#      }
#     ],
#     "aggregaterating": [
#      {
#       "ratingvalue": "3.0",
#       "reviewcount": "95"
#      }
#     ],
#     "postaladdress": [
#      {
#       "streetaddress": "371 Washington St",
#       "addresslocality": "Newton Corner",
#       "addressregion": "MA",
#       "postalcode": "02458"
#      }
#     ],
#     "localbusiness": [
#      {
#       "name": "Honda Village",
#       "telephone": "(888) 848-1441",
#       "ratingvalue": "3.0",
#       "reviewcount": "64"
#      }
#     ],
#     "rating": [
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "1.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "4.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "1.0"
#      },
#      {
#       "ratingvalue": "2.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "4.0"
#      },
#      {
#       "ratingvalue": "1.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "4.0"
#      },
#      {
#       "ratingvalue": "1.0"
#      },
#      {
#       "ratingvalue": "4.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "1.0"
#      },
#      {
#       "ratingvalue": "2.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "1.0"
#      },
#      {
#       "ratingvalue": "1.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "2.0"
#      },
#      {
#       "ratingvalue": "2.0"
#      },
#      {
#       "ratingvalue": "1.0"
#      },
#      {
#       "ratingvalue": "2.0"
#      },
#      {
#       "ratingvalue": "1.0"
#      },
#      {
#       "ratingvalue": "1.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "2.0"
#      },
#      {
#       "ratingvalue": "2.0"
#      },
#      {
#       "ratingvalue": "4.0"
#      },
#      {
#       "ratingvalue": "1.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      }
#     ],
#     "metatags": [
#      {
#       "viewport": "width=1020",
#       "application-name": "Yelp",
#       "msapplication-tileimage": "http://s3-media3.fl.yelpcdn.com/assets/2/www/img/7f906850f02b/ico/win8-tile.png",
#       "msapplication-tilecolor": "#c41200",
#       "msapplication-starturl": "http://www.yelp.com/",
#       "msapplication-navbutton-color": "#c41200",
#       "msapplication-window": "width=1024;height=768",
#       "msapplication-tooltip": "Go to Yelp.com",
#       "msapplication-task": "name=Find Reviews; action-uri=/; icon-uri=http://s3-media1.fl.yelpcdn.com/assets/2/www/img/a6bbc59c7458/ico/favicon-16x16.ico",
#       "apple-itunes-app": "app-id=284910350, app-argument=yelp:///biz/EkjITiBxgyTVxy_NWZJyJw?campaign=default&source=www&utm_campaign=default&utm_source=www",
#       "theme-color": "#c41200",
#       "fb:app_id": "97534753161",
#       "og:description": "Specialties: For 40+ years now, Honda Village has been proud to present one of the world's truly great line-up of automobiles in a convenient and fun atmosphere.  We are tucked into Newton Corner, incredibly close by for most of greater",
#       "og:image": "http://s3-media2.fl.yelpcdn.com/bphoto/ciCFr6ZIplthauOv8MSNBg/o.jpg",
#       "og:site_name": "Yelp",
#       "og:title": "Honda Village - Newton Corner, MA",
#       "og:type": "yelpyelp:business",
#       "og:url": "http://www.yelp.com/biz/honda-village-newton-corner",
#       "og:image:width": "1142",
#       "og:image:height": "498",
#       "twitter:app:name:googleplay": "Yelp",
#       "twitter:app:url:ipad": "yelp:///biz/EkjITiBxgyTVxy_NWZJyJw?campaign=default&source=twitter-card&utm_campaign=default&utm_source=twitter-card",
#       "twitter:domain": "yelp.com",
#       "twitter:app:name:iphone": "Yelp",
#       "twitter:app:name:ipad": "Yelp",
#       "twitter:app:url:googleplay": "android-app://com.yelp.android/yelp-app-indexing/biz/EkjITiBxgyTVxy_NWZJyJw?utm_medium=organic&utm_source=google",
#       "twitter:site": "@yelp",
#       "twitter:app:id:googleplay": "com.yelp.android",
#       "twitter:app:id:iphone": "id284910350",
#       "twitter:app:url:iphone": "yelp:///biz/EkjITiBxgyTVxy_NWZJyJw?campaign=default&source=twitter-card&utm_campaign=default&utm_source=twitter-card",
#       "twitter:card": "summary",
#       "twitter:app:id:ipad": "id284910350",
#       "yelp-biz-id": "EkjITiBxgyTVxy_NWZJyJw"
#      }
#     ],
#     "hreviewaggregate": [
#      {
#       "count": "95"
#      }
#     ],
#     "review": [
#      {
#       "ratingstars": "3.0",
#       "ratingcount": "95"
#      },
#      {
#       "author": "Valerie K.",
#       "datepublished": "2015-05-17",
#       "description": "Last month I purchased a 2012 Civic at Honda Village. I had done my research and my choice was between a Honda Civic or a Toyota Corolla. They're both excellent cars but I choose the Civic..."
#      },
#      {
#       "author": "Evan D.",
#       "datepublished": "2015-05-02",
#       "description": "I purchased a new Honda Accord EX-L (CVT I4) from Honda Village. Jim, my salesperson, was excellent and a pleasure to work with throughout the process. He respected my opinion/preferences (e.g.,..."
#      },
#      {
#       "author": "Lisa C.",
#       "datepublished": "2015-04-04",
#       "description": "I had finally come to the conclusion that I wanted a new car. My mother's car was falling apart, so all I wanted was to give her my car, which was in great shape, and get a new one for myself...."
#      },
#      {
#       "author": "AnnMarie P.",
#       "datepublished": "2015-02-23",
#       "description": "Unbeatable Customer Service From the second you walk into the door at Honda Village in Newton you are greeted with courtesy and professionalism. From the front desk, to the sales office everyone..."
#      },
#      {
#       "author": "Lidya D.",
#       "datepublished": "2015-02-09",
#       "description": "I bought a \"new\" CRV 4 months ago from Honda Village and there's been SO many problems with the car. The wiper blades started streaking (after just 4 months?!), the wiper fluid pipe freezes..."
#      },
#      {
#       "author": "Carl P.",
#       "datepublished": "2015-02-24",
#       "description": "Outstanding sales and service operation, the best Honda people in the area. We have three Honda's under our roof, all purchased and succeed at Honda Village."
#      },
#      {
#       "author": "Dre L.",
#       "datepublished": "2015-06-09",
#       "description": "It is very rare to hear someone say great things about a dealership when buying a car, but I couldn't have had an easier or more comfortable experience than I did at Honda Village. These guys..."
#      },
#      {
#       "author": "D S.",
#       "datepublished": "2015-03-25",
#       "description": "We didn't buy a car from them because they don't accept financing from DCU, but we had a great experience with their sales staff. Manny Zabatta is a great person to work with: very responsive,..."
#      },
#      {
#       "author": "Amy D.",
#       "datepublished": "2015-03-02",
#       "description": "Today they took in my Jeep, no appointment, looked at it right away, and referred me to a Jeep specialist down the street, gave me directions to jeep place, no charge, no waiting, super polite & nice."
#      },
#      {
#       "author": "Steve W.",
#       "datepublished": "2014-08-01",
#       "description": "I've read reviews for most car dealers and they all seem to avg 2.5 stars. And plenty of not so pleasant experiences. However this seems to be how most car dealers operate. With that in mind..."
#      },
#      {
#       "author": "Jessica B.",
#       "datepublished": "2013-12-28",
#       "description": "This review is once again for service only. My husband brought my car in because I have bronchitis and this place gives me the vapors anyway. Well, contrary to their advertising, they would..."
#      },
#      {
#       "author": "C C.",
#       "datepublished": "2015-05-06",
#       "description": "I have seen better run dealerships, but on the service side, Calvin makes the service experience very satisfactory. Definitely the best guy for service advice, to handle your repairs and to..."
#      },
#      {
#       "author": "Fiji G.",
#       "datepublished": "2014-10-25",
#       "description": "It's rare that I have a positive experience at a car dealership, so I'm taking the time to write a positive review for these folks. As a young independent lady person, I've endured a *lot*..."
#      },
#      {
#       "author": "Sebastian J.",
#       "datepublished": "2015-01-15",
#       "description": "I purchased my car from this dealer ship back in 2007 and my brother also purchased his Honda Accord in 2014. As much as we had a decent buying experience here, there service salesman (who..."
#      },
#      {
#       "author": "Mike S.",
#       "datepublished": "2014-09-19",
#       "description": "i have never felt so at home in a car dealership in my life. This is due, to a great deal, to Barry Teicholz. I met Barry early this year when my Nephew wanted to get a new Honda Civic SI,..."
#      },
#      {
#       "author": "Ariel Z.",
#       "datepublished": "2014-01-07",
#       "description": "I leased my 2009 Honda Civic for 3 years after finally buying it. However, it is not advisable to buy a leased car if you already know that you will want to buy it. This was not the case for..."
#      },
#      {
#       "author": "Sheila R.",
#       "datepublished": "2015-01-04",
#       "description": "I wouldn't even give this dealership a one-star but that's my only option. I originally bought a new Honda Pilot in 2002, when they first came out. The car has been great for many years, without..."
#      },
#      {
#       "author": "Julia H.",
#       "datepublished": "2014-06-17",
#       "description": "I bought my car here in 2010 and I also got the extended warranty for 6 years. I have had barely any problems with my car, but every time I have come in for an oil change or anything I have..."
#      },
#      {
#       "author": "Jeremy P.",
#       "datepublished": "2014-12-16",
#       "description": "I live in Boston, and it would have been far easier to walk 15 minutes down the street and buy from Herb Chambers. What swayed me to buy from Honda Village was the exemplary service from salesperso..."
#      },
#      {
#       "author": "Katie G.",
#       "datepublished": "2014-09-17",
#       "description": "If I could give zero stars, I would. I brought my car in because the check engine light had turned on. They were able to schedule an appointment for me early the next day and mentioned that..."
#      },
#      {
#       "author": "Jessica C.",
#       "datepublished": "2014-02-06",
#       "description": "Recently bought a used civic through Georgi. We nearly walked out because of the extremely rude man that worked in the finance department. Every time we returned there was some sort of story..."
#      },
#      {
#       "author": "Nina H.",
#       "datepublished": "2014-09-19",
#       "description": "I recently leased a car here and couldn't have asked for better service. I was immediately greeted by a very friendly receptionist. Her name slips my mind at the moment but Denny, the sales..."
#      },
#      {
#       "author": "Kara Z.",
#       "datepublished": "2014-09-19",
#       "description": "I've purchased 4 cars from Honda Village and get all my service done by these guys. Top notch from day 1 treating me with respect. I appreciate all the help through the years. As soon as the..."
#      },
#      {
#       "author": "Nick D.",
#       "datepublished": "2013-11-22",
#       "description": "They sold me a car. Within 2 months it needed $2000 in repairs. I continually went in asking for them to repair it within the 30 day period. They refused to repair it. Then my mechanic told..."
#      },
#      {
#       "author": "Sergey B.",
#       "datepublished": "2014-09-03",
#       "description": "Don't go there. Customer service sucks. They offered 1/4 of what my trade in worth on kbb , saying my car was hit and painted blah blah blah. So freaking ridiculous cause I know it wasn't!..."
#      },
#      {
#       "author": "Peter M.",
#       "datepublished": "2014-09-19",
#       "description": "Been searching for a Car for many months and I wanted the most for my trade in and Honda village in newton did it. I got the right Accord and the right color. I'm a difficult person I know..."
#      },
#      {
#       "author": "Michael J.",
#       "datepublished": "2014-08-26",
#       "description": "I purchased two cars (Civic and Accord Coupe, base models) from them a couple weeks ago. I had previously visited Boch and Bernardi prior to coming here. Boch had the price right, but Bernardi..."
#      },
#      {
#       "author": "Thanh H.",
#       "datepublished": "2013-02-28",
#       "description": "I've gotten two cars here and both times the salesperson (Peter Ly) was very helpful. He was able to answer all my questions and gave me his honest opinion when comparing specs between cars...."
#      },
#      {
#       "author": "K. L.",
#       "datepublished": "2014-06-19",
#       "description": "So I used to think this place was great but in the past couple of years it's gotten super sketchy. You always have to wait at least an hour and a half, regardless of having an appointment...."
#      },
#      {
#       "author": "K R.",
#       "datepublished": "2013-07-27",
#       "description": "I had clearly gone over what I was paying for and not paying for with both the person who sold me the car and also the finance manager at the dealership. I negotiated what I would pay up front..."
#      },
#      {
#       "author": "Sarah T.",
#       "datepublished": "2014-12-05",
#       "description": "I used to take my car here when I felt like I needed car stuff that catered to my honda. I prefer the local mechanic but recently had a lock issue so went back to Honda Village. They fixed..."
#      },
#      {
#       "author": "Surina S.",
#       "datepublished": "2013-06-18",
#       "description": "I bought a Honda Civic LX 2013 from Honda Village. Overall the experience was just okay. I am writing this review to tell you that I did not get all weather floor mats as was promised to me...."
#      },
#      {
#       "author": "Patricia M.",
#       "datepublished": "2014-08-12",
#       "description": "I contacted Honda Village through the website regarding a particular pre-owned car. The salesman immediately reached out to me. I made an appointment on my lunch hour to take the train from..."
#      },
#      {
#       "author": "Dave M.",
#       "datepublished": "2012-03-23",
#       "description": "SERVICE CENTER review: large guy at the service reception desk who i think is the manager is super rude. he's bitter at life so he's rude to customers and even co-workers. then he called me..."
#      },
#      {
#       "author": "Kimsley A.",
#       "datepublished": "2014-09-19",
#       "description": "I have nothing but positive things to say about Honda Village. I had been shopping for cars at other dealerships and none of them are comparable to the caliber of customer service and the depth..."
#      },
#      {
#       "author": "Evan N.",
#       "datepublished": "2014-03-08",
#       "description": "I have gone here a few time for car services. Today I felt like a hot potato in the services department. staff member passes me around, I feel soo discriminated against,. Thanks goodness Calvin..."
#      },
#      {
#       "author": "Sheila R.",
#       "datepublished": "2013-11-18",
#       "description": "I've been a loyal customer for 20+ years of Honda Village. Recently I was told they won't honor a warranty based on a technicality. Unfortunately that they don't seem to recognize a good paying..."
#      },
#      {
#       "author": "Barbara A.",
#       "datepublished": "2013-01-30",
#       "description": "There is nothing I like about car shopping except when you actually drive off the lot with your new car. I find it to be a painful and arduous process. We went to several dealerships to look..."
#      },
#      {
#       "author": "Santosh C.",
#       "datepublished": "2014-01-26",
#       "description": "Very poor customer service at the service station. Very unprofessional staff. Had been there for factory recall service."
#      },
#      {
#       "author": "Meg N.",
#       "datepublished": "2013-09-27",
#       "description": "I am giving this place five stars due to one person...Peter Ly. I gave him a serious challenge in a lease that needed a co-signer with my credit. My credit isn't terrible but certainly not..."
#      }
#     ],
#     "breadcrumb": [
#      {
#       "url": "Automotive",
#       "title": "Automotive"
#      },
#      {
#       "url": "Auto Repair",
#       "title": "Auto Repair"
#      },
#      {
#       "url": "Automotive",
#       "title": "Automotive"
#      },
#      {
#       "url": "Car Dealers",
#       "title": "Car Dealers"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "DriveTime Used Cars Reviews | Car Dealers | Jacksonville, FL ...",
#    "htmlTitle": "DriveTime Used Cars Reviews | Car Dealers | Jacksonville, FL \u003cb\u003e...\u003c/b\u003e",
#    "link": "http://reviews.birdeye.com/drivetime-used-cars-929013824",
#    "displayLink": "reviews.birdeye.com",
#    "snippet": "She's an asset to the company. Amy Olson. May 09 ... I literally drove into the \nparking lot with no more ability left in my car. .... My name is Kelley Soly and I just \nfinanced a car thru Drivetime after my car was totalled in an accident. Chemeka...",
#    "htmlSnippet": "She&#39;s an \u003cb\u003easset\u003c/b\u003e to the company. Amy Olson. May 09 ... I literally drove into the \u003cbr\u003e\nparking lot with no \u003cb\u003emore\u003c/b\u003e ability left in my car. .... My name is \u003cb\u003eKelley\u003c/b\u003e Soly and I just \u003cbr\u003e\nfinanced a car thru Drivetime after my car was totalled in an accident. Chemeka&nbsp;...",
#    "cacheId": "zrRW1q8LXRUJ",
#    "formattedUrl": "reviews.birdeye.com/drivetime-used-cars-929013824",
#    "htmlFormattedUrl": "reviews.birdeye.com/drivetime-used-cars-929013824",
#    "pagemap": {
#     "cse_image": [
#      {
#       "src": "http://d3cnqzq0ivprch.cloudfront.net/reviews/css/images/profile/p-auto02.jpg"
#      }
#     ],
#     "aggregaterating": [
#      {
#       "ratingvalue": "4.7",
#       "reviewcount": "68"
#      }
#     ],
#     "postaladdress": [
#      {
#       "streetaddress": "10384 Atlantic Blvd",
#       "addresslocality": "Jacksonville",
#       "addressregion": "FL",
#       "postalcode": "32225",
#       "addresscountry": "US"
#      }
#     ],
#     "localbusiness": [
#      {
#       "name": "DriveTime Used Cars Reviews",
#       "telephone": "(904) 302-9329",
#       "maps": "http://maps.google.com/maps?q=10384 Atlantic Blvd, Jacksonville, FL, 32225&hl=en",
#       "image": "http://d3cnqzq0ivprch.cloudfront.net/reviews/css/images/profile/p-auto02.jpg",
#       "description": "DriveTime is setting new standards for the subprime used car dealer industry. Buying a used car with credit issues can be very difficult and actually put you in a worse position than you were..."
#      }
#     ],
#     "rating": [
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "1.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "4.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "4.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "1.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "1.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "4.0"
#      },
#      {
#       "ratingvalue": "1.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "5.0"
#      },
#      {
#       "ratingvalue": "1.0"
#      }
#     ],
#     "metatags": [
#      {
#       "viewport": "width=device-width, initial-scale=1.0",
#       "fragment": "!",
#       "og:title": "DriveTime Used Cars",
#       "og:description": "Read reviews about DriveTime Used Cars from Jacksonville, FL. Rated 4.7 / 5 by 68. Calvin Wright is remarkable. He was courteous, efficient and simply amazing. Thank you Calvin for making our 'new' car a reality!",
#       "og:type": "Company",
#       "og:image": "http://d3cnqzq0ivprch.cloudfront.net/reviews/css/images/profile/p-auto02.jpg",
#       "og:url": "http://reviews.birdeye.com/drivetime-used-cars-929013824"
#      }
#     ],
#     "hreviewaggregate": [
#      {
#       "count": "68"
#      }
#     ],
#     "review": [
#      {
#       "ratingstars": "4.5",
#       "ratingcount": "68",
#       "image_url": "http://d3cnqzq0ivprch.cloudfront.net/reviews/css/images/profile/p-auto02.jpg"
#      },
#      {
#       "author": "Sherrie Rabe",
#       "datepublished": "2015-06-05",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Calvin Wright is remarkable. He was courteous, efficient and simply amazing. Thank you Calvin for making our 'new' car a reality!"
#      },
#      {
#       "author": "Fredrickca Pelsey",
#       "datepublished": "2015-05-09",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Chemeka Edward gave very good service. She was very personable and friendly. I was impress by her probing me to find the best deal. She's an asset to the company."
#      },
#      {
#       "author": "Amy Olson",
#       "datepublished": "2015-05-09",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Chemeka Edwards was awesome. She took great care of us and made everything work so we got the car we came in for. I will definitely tell people about my experience here."
#      },
#      {
#       "author": "Taryn Williams",
#       "datepublished": "2015-05-09",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "My experience was amazing from the I stepped foot into drivetime I received nothing but great service. Justin, Calvin, and Larry they are great and did a fantastic job at explaining things..."
#      },
#      {
#       "author": "Tonya Price",
#       "datepublished": "2015-05-09",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Jay provided excellent service and also the other staff"
#      },
#      {
#       "author": "April Taylor",
#       "datepublished": "2015-05-02",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "My daughter Ciara Bentley was represented by Chemeka Edwards in the purchase of her new car....Ya Ciara!"
#      },
#      {
#       "author": "cameron dean",
#       "datepublished": "2015-05-02",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "The experience at drivetime was exactly the kind of service I was looking for. I literally drove into the parking lot with no more ability left in my car. Calvin helped me personally along..."
#      },
#      {
#       "author": "Stephanie Delne",
#       "datepublished": "2015-04-25",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I just purchased my 3rd vehicle from Drivetime with Chemeka. She is awesome."
#      },
#      {
#       "author": "Richard Morgan",
#       "datepublished": "2015-04-25",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Chemeka Edwards was great with my parents William & Olive Morgan who purchased a 2013 Chevrolet Impala."
#      },
#      {
#       "author": "Jayla Awa",
#       "datepublished": "2015-04-25",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Chemeka Edwards was an amazing help, this was our second lease. She made the car shopping and purchase experience easy. Thank you for you help Chemeka and the staff at Drive Time Atlantic Blvd."
#      },
#      {
#       "author": "Sheriko Johnson",
#       "datepublished": "2015-04-16",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I got all my questions answered,I like how everything was put together from beginning til end I was taking care of very well ms Chemeka was heck of awesome though the whole thing.she was the..."
#      },
#      {
#       "author": "A Google User",
#       "datepublished": "2015-04-16",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I had a wonderful experience here with my rep Chemeka Edwards... she was very professional, understanding and no pressure..... work with my budget and got me in a car.... I will be referring..."
#      },
#      {
#       "author": "Carolyn Newton",
#       "datepublished": "2015-04-16",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Chemeka Edwards rocks! Excellent customer service."
#      },
#      {
#       "author": "Tony Aponte",
#       "datepublished": "2015-04-16",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I have to say that it was an awesome experience at Drivetime. Chemeka and Larry were great. I was really impressed."
#      },
#      {
#       "author": "Laura Stewart",
#       "datepublished": "2015-04-11",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Chemeka was very helpful in getting us our jeep today,and her personality was awesome!!!"
#      },
#      {
#       "author": "Merle Unger",
#       "datepublished": "2015-04-11",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "First I would like to describe my experience is drive time is absolutely wonderful and an exhilarating I was able to go in and drive away in my new car in the same day no hustling around no..."
#      },
#      {
#       "author": "Ja'Nea Ross",
#       "datepublished": "2015-04-11",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I was very impressed how fast & the whole approval process had taken. I didn't have all the money to put down on my vehicle therefore, the dealership allowed me to reserve the car w/ a small..."
#      },
#      {
#       "author": "Cambrey Johnson",
#       "datepublished": "2015-04-11",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Came into Drivetime after being denied at multiple other dealerships because my husband and I have no credit history, a lot of the places were wanting over 3,000 down even Kia Southside although..."
#      },
#      {
#       "author": "Sheree Allen",
#       "datepublished": "2015-04-04",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Chemeka was my sales person and she was awesome. She was very. knowledgeable got me into my car right before work. Go see Chemeka at drivetime on Atlantic."
#      },
#      {
#       "author": "giovannilaws",
#       "datepublished": "2015-04-04",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I'm creole and I have got my first car from drive time on atlantic blvd .when I got there I didn't see a car I liked from the lot , so I seen a Ford I liked from Orlando. And I really liked..."
#      },
#      {
#       "author": "KashKaysKarma",
#       "datepublished": "2015-04-04",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Chemeka Edwards was wonderful. . she helped me complete all paper work and has great customer service. .I loved my experience with her. ."
#      },
#      {
#       "author": "Christine Doyle",
#       "datepublished": "2015-04-04",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I very easy process with drive time they were helpful and it didnt take long especially Allison thanks for the easy process"
#      },
#      {
#       "author": "Jessica Clark",
#       "datepublished": "2015-04-04",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Allison was a great person. She is very friendly. I'm glad she could help us out with what we were looking for. We got the exact car we wanted. We couldn't have a better person to help us out! :)"
#      },
#      {
#       "author": "Hayden Clasen",
#       "datepublished": "2015-04-04",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "We went to drive time to buy a car all the employees were very polite and seemed interested in helping us find the car that would fit our needs especially Calvin and Justin"
#      },
#      {
#       "author": "Jensen Soly",
#       "datepublished": "2015-04-04",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "My name is Kelley Soly and I just financed a car thru Drivetime after my car was totalled in an accident. Chemeka Edwards was my sales advisor. She radiates sincerity, kindness, and warmth...."
#      },
#      {
#       "author": "Natasha Berryman",
#       "datepublished": "2015-04-04",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Chemeka was so sweet friendly down to earth made it as easy and stress free thank u so mucch for yur help chemeka!!:)"
#      },
#      {
#       "author": "Sasha Rochelle",
#       "datepublished": "2015-04-04",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I love everyone at drive time they helped us get the car we wanted even if it wasn't in Jacksonville. those guys are awesome and appreciate everything they've done in helping find the best..."
#      },
#      {
#       "author": "Myrendia Carter",
#       "datepublished": "2015-03-28",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "This was a great pleasure working with Chemeka Edwards. After having a bad experience at the Savannah location, she and the General Manager were great"
#      },
#      {
#       "author": "Richard Bailey",
#       "datepublished": "2015-03-28",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "apon entery we were greated by a very plesent and patient Chemeka. My wife is handicapped and Chemeka was very helpful in assisting her. Chemeka has an Outstanding disposition. Very knowledgeable,..."
#      },
#      {
#       "author": "matthew scott",
#       "datepublished": "2015-03-28",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Approved me for a car when no one else would. Got me a car im happy with at a price i can afford"
#      },
#      {
#       "author": "Brian Baker",
#       "datepublished": "2015-03-21",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Chemeka edwards was awesome and very helpful. I will definitely refer others to come to drivetime just because of her!"
#      },
#      {
#       "author": "Susan Smith",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Justin Avery gave excellent service very pleased with my purchase will recommend him to everyone. thank you"
#      },
#      {
#       "author": "Megan Pullen",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Chemeka was absolutely amazing! My spouse clinton and I have had so many bad experiences when trying to buy a car in the past. We got an amazing deal and she helped us find the perfect car for us!"
#      },
#      {
#       "author": "Jeffrey Dumm",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "As a 10 Year Salesperson, I have been absolutely disgusted by the lack of professionalism and customer service from the local dealerships and craigslist postings in Jacksonville. I strive everyday..."
#      },
#      {
#       "author": "Ashlee Gray",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Amazing, Chemeka Edwards was our salesWOMAN and she was very helpful. My friend Anitra Aljada felt like she would never get a car of her OWN and after a let down at the bank we stopped into..."
#      },
#      {
#       "author": "clinton wood",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Chemeka Edwards made buying my first car easy. Set me and my spouse megan up with the perfect car!"
#      },
#      {
#       "author": "Ashley Hoffman",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Chemeka Edwards was amazing she made me feel at home didn't push me into anything I didn't want she got me in the car I wanted for the price I wanted will refer others to her"
#      },
#      {
#       "author": "daniel avila",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Chemeka Edwards and Justin Avery were amazing. They were very helpful and to the point. They went out of their way to answer any questions. I had an excellent experience at Drive Time and would..."
#      },
#      {
#       "author": "Roosevelt Williams",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I had a great experience at drivetime. Chemeka was very pleasant and professional and i would send any and everyone to see Chemeka at Drivetime."
#      },
#      {
#       "author": "Michael Deosca",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Chameka was amazing. she went and got the car for me... did everything possible and even held my infant to calm her down while I finished the paperwork. No other dealership would have done..."
#      },
#      {
#       "author": "Mark Grant",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Chemeka Edwards was have have nice she took the time too show me my car and she didn't make me fell like a customer..she made me fill more like family."
#      },
#      {
#       "author": "Lori Wanzo",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "It was awesome and very quick. Justin Avery was our sales rep and he was great!"
#      },
#      {
#       "author": "Garry Haws",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I drove to the Atlantic Blvd. location (40+ miles) to look at a truck I was interested in. It was sold! But, with the \"Outstanding\" and curtious help I received form \"Allison Fischer\", I I..."
#      },
#      {
#       "author": "Denis Meyer",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Chemeka Edwards was our sales person today,she was so helpful and friendly. Would recommend her and the company to my family and friends."
#      },
#      {
#       "author": "Kinya Jackson",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I had a FANTASTIC first experience at Drive Time. My sales associate Justin Avery was extremely helpful and made sure that I was completely comfortable with every step in the process of obtaining..."
#      },
#      {
#       "author": "Gena Rogers",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Calvin is awesome, he is very personable and did an awesome job!"
#      },
#      {
#       "author": "Danielle Davila",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I'm leasing a car from drive time and Chemeka Edwards helped me find a car for me and my son. She has amazing customer service and kept a smile on my face. I am satisfied and would recommend..."
#      },
#      {
#       "author": "joaquin vilanova",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Great service, he is the Best I am a repeat customer and will soon be a tre-peat, Justin Avery great sales guy."
#      },
#      {
#       "author": "Deatoni James",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I love the service and very helpful. I enjoyed the service from justin."
#      },
#      {
#       "author": "Tralecia Gainer",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "My experience with Drivetime was awesome.. My agent Justin Avery was great he explained everything to me and made me feel so comfortable about my purchase. My credit Isnt great, but I still..."
#      },
#      {
#       "author": "Epiphany Rivera",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I had a wonderful experience at drive time with Chameka, she will go the extra mile to make sure you are satisfied with your purchase, very professional."
#      },
#      {
#       "author": "Nystareia Mosley",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Jay Doakes was a very helpful guy. He showed that he was very caring and passionate about his job and was kind about finding the right vehicle that best fit our needs. If you are every looking..."
#      },
#      {
#       "author": "Brandon Cebalt",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Chemeka was amazing, fun, and very helpful throughout the buying process."
#      },
#      {
#       "author": "Megan U",
#       "datepublished": "2015-03-19",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Jay took great care of us! We weren't expecting to get a car, but he worked with us to find an even better deal than we could have imagined!!! Thank you Jay!"
#      },
#      {
#       "author": "Joaquin V.",
#       "datepublished": "2015-02-24",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Drive Time is a great used car deale. Justin Avery is the best sales guy, great combination. They have quality cars, presented clean and professionaly. The sales people are educated and professiona..."
#      },
#      {
#       "author": "Bob W.",
#       "datepublished": "2015-02-20",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I have worked for other dealerships, and drivetime was up front, honest, open and gave a greater value than the rest of the used car dealers in the area. The warranty and service plan is extra..."
#      },
#      {
#       "author": "michel mulanax",
#       "datepublished": "2015-02-16",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I just bought my 1 st car at DriveTime on Atlantic Blvd and I am more than pleased. Chemeka Edwards was knowledgeable, going above and beyond, making it a quick and painless process. Thank you!!!"
#      },
#      {
#       "author": "Victoria Witcher",
#       "datepublished": "2015-02-16",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I just purchased a car from here and I wanted to give a HUGE shoutout to Chemeka. She is an amazing sales person with an amazing personality to match. She has great customer service skills..."
#      },
#      {
#       "author": "John Register",
#       "datepublished": "2015-02-16",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I just bought my 2nd car with them and love it as much this time as I did my last! They are friendly and funny as well as have a great selection. Chameka really stood out as an awesome example..."
#      },
#      {
#       "author": "anitre1214",
#       "datepublished": "2015-02-16",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Just bought my 3rd vehicle today. We a very grateful for DT for helping us improve our credit score and the customer service was outstanding. We would like to say \"thank you\" to our sales rep,..."
#      },
#      {
#       "author": "Janice Warner",
#       "datepublished": "2015-02-16",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I loved the service escpecially Chameka Edwards! She helped us find the right vehicle for the right price. Her personality was very friendly and welcoming. We love the car and will definitely..."
#      },
#      {
#       "author": "Mike Householder",
#       "datepublished": "2015-02-16",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I walked in with the intent to walk out with a 2010 Chevy Equinox, found it online and wanted it. When I got there I met Justin, and he helped me tremendously. My credit sucks, but he gave..."
#      },
#      {
#       "author": "Robert Johnson",
#       "datepublished": "2015-02-16",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "We just purchased our 3rd vehicle with DT. We had Chemeka Edwards as our sales rep who represented DT with professionalism, upbeat personality and great knowledge of the cars! We are very happy..."
#      },
#      {
#       "author": "sthomas904",
#       "datepublished": "2014-05-24",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Great staff, Got a car with nothing down using my truck as a trade in.Thanks guys"
#      },
#      {
#       "author": "Cotina W.",
#       "datepublished": "2014-04-22",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Allison and Reggie are great to work with on getting a car. I really appreciated the laughs and smiles that were given and shared through this transaction. Thanks again!!!!"
#      },
#      {
#       "author": "Antonio",
#       "datepublished": "2014-01-13",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I ENJOYEYED, DEALING WITH PEOPLE WHO REALLY WANTED TO MAKE YOU HAPPY ,AND NOT JUST GET A SALE. THANKS DRIVETIME"
#      },
#      {
#       "author": "Deprina G.",
#       "datepublished": "2013-10-02",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I bought my car from here!! Good place to go if you need a credit improvement. Tell them Deprina G sent ya lol"
#      },
#      {
#       "author": "W.M. S.",
#       "datepublished": "2013-04-03",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "WORST CAR BUYING EXPERIENCE!! I've had my car for one week and it is at the BMW dealership right now for the second time!! Drivetime and its associates have been of no assistance. In one weeks..."
#      },
#      {
#       "author": "A Google User",
#       "datepublished": "2013-02-27",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I was in and out in about 1 1/2 hrs. I test drove 3 cars and the salesman gave the good and not so good about each vehicle. My credit score was 451 and I was approved at what I could afford...."
#      },
#      {
#       "author": "Stephanie H.",
#       "datepublished": "2012-08-14",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "I just purchased a used vehicle from DriveTime. My sales manager Candace was very very helpful and she listened to what I needed and helped me get into a vehicle that I could afford. Very professio..."
#      },
#      {
#       "author": "A Google User",
#       "datepublished": "2012-02-28",
#       "itemreviewed": "DriveTime Used Cars",
#       "reviewbody": "Who names themselves \"Happy dt customer\"Drivetime is a scam, there is no way your gonna get a car in one hour... if your financial status was that good you would be better off just going to..."
#      },
#      {
# ...
#      },
#      {
#       "text": "The biggest risk of open-source CRM is quality control."
#      },
#      {
#       "text": "_____ is a CRM system that is hosted by an external vendor in the vendor's data center."
#      },
#      {
#       "text": "The benefits of open-source CRM include all of the following except:"
#      },
#      {
#       "text": "The flows in supply chains consist of which of the following?"
#      },
#      {
#       "text": "A demand chain refers to the flow of materials, information, money, and services from suppliers to the end customer."
#      },
#      {
#       "text": "_____ are the physical products, raw materials, and supplies that flow along a supply chain."
#      },
#      {
#       "text": "Supply chain management systems are a type of transaction processing system."
#      },
#      {
#       "text": "The pull model is most closely associated with mass customization."
#      },
#      {
#       "text": "The push model is most closely associated with mass production."
#      },
#      {
#       "text": "Problems along the supply chain include which of the following?"
#      },
#      {
#       "text": "NOT a limitation of EDI:"
#      },
#      {
#       "text": "Electronic data interchange is a communication standard that enables the electronic transfer of routine documents between business partners."
#      },
#      {
#       "text": "Business environment pressures can come from which of the following?"
#      },
#      {
#       "text": "Thomas Friedmans flatteners include which of the following?"
#      },
#      {
#       "text": "Which of the following pressures do businesses today experience?"
#      },
#      {
#       "text": "Which of the following is not a government regulation that puts pressure on businesses?"
#      },
#      {
#       "text": "What are organizational responses to various business pressures?"
#      },
#      {
#       "text": "Which of the following is an example of a technology pressure faced by businesses?"
#      },
#      {
#       "text": "According to Michael Porter, the Web ______ competition, which generally _________ a firms profitability."
#      },
#      {
#       "text": "According to Porters Value Chain Model, which of the following are considered support activities?"
#      },
#      {
#       "text": "Cost Leadership Strategy is one strategy to gain a competitive advantage?"
#      },
#      {
#       "text": "Two strategies that a company can use to gain a competitive advantage are?"
#      },
#      {
#       "text": "There are six (6) characteristics of effective Business-IT Alignment."
#      },
#      {
#       "text": "Which of the following is a characteristic of effective business  IT alignment?"
#      },
#      {
#       "text": "The procurement process is comprised of ______ steps that are completed in _____ different functional areas of the firm."
#      },
#      {
#       "text": "The fulfillment process is triggered when _______________ receives a purchase order."
#      },
#      {
#       "text": "Information systems play a vital role in which of the following functions?"
#      },
#      {
#       "text": "___________ is a management technique that includes methods and tools to support the design, analysis, implementation management and optimization of business processes."
#      },
#      {
#       "text": "Information Technology is a key enabler of business process reengineering (BPR)."
#      },
#      {
#       "text": "The amount of data is increasing exponentially over time."
#      },
#      {
#       "text": "It is very difficult to manage data for which of the following reasons?"
#      },
#      {
#       "text": "When customers access a Web site and make purchases, they generate _____."
#      },
#      {
#       "text": "The primary key is a field that uniquely and completely identifies a record."
#      },
#      {
#       "text": "In a relational database, the customer record contains information regarding the customer's last name. The last name is a(n):"
#      },
#      {
#       "text": "When various copies of the data agree, this is an example of data integrity."
#      },
#      {
#       "text": "Place the following members of the data hierarchy in the correct order:"
#      },
#      {
#       "text": "A(n) _____ is a logical grouping of related fields."
#      },
#      {
#       "text": "In a database, the primary key field is used to _____."
#      },
#      {
#       "text": "Normalization is a method for eliminating redundant data elements."
#      },
#      {
#       "text": "The data dictionary defines the format necessary to enter data into a database."
#      },
#      {
#       "text": "Data dictionaries perform all of the following functions except:"
#      },
#      {
#       "text": "A standardized language used to manipulate data is _____."
#      }
#     ],
#     "collegeoruniversity": [
#      {
#       "name": "Virginia Commonwealth University"
#      }
#     ],
#     "metatags": [
#      {
#       "fb:app_id": "102540830008",
#       "viewport": "width=device-width, initial-scale=1.0, maximum-scale=1.0",
#       "apple-itunes-app": "app-id=323887414, app-argument=studyblue://study?docID=8700562&docType=0&docSubType=12",
#       "og:title": "Information Systems 360 \u003e Chin \u003e Flashcards \u003e IS 360 Study Guide (2013-14 Chin) | StudyBlue",
#       "og:type": "studyblue:deck",
#       "og:url": "https://www.studyblue.com/notes/note/n/is-360-study-guide-2013-14-chin/deck/8700562",
#       "og:description": "Find and study online flashcards from Information Systems 360. Visit StudyBlue today to learn more!",
#       "og:image": "https://classconnection.s3.amazonaws.com/images/fb-og-deck.png",
#       "studyblue:cards": "2487",
#       "studyblue:created": "2013-11-20",
#       "og:site_name": "StudyBlue",
#       "twitter:image:src": "https://classconnection.s3.amazonaws.com/images/fb-og-deck.png",
#       "twitter:card": "summary",
#       "twitter:site": "@studyblue",
#       "twitter:title": "Information Systems 360 \u003e Chin \u003e Flashcards \u003e IS 360 Study Guide (2013-14 Chin) | StudyBlue",
#       "twitter:description": "Find and study online flashcards from Information Systems 360. Visit StudyBlue today to learn more!"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Kellie Dixon - Address, Phone, Public Records - Radaris",
#    "htmlTitle": "Kellie Dixon - Address, Phone, Public Records - Radaris",
#    "link": "http://radaris.com/p/Kellie/Dixon/",
#    "displayLink": "radaris.com",
#    "snippet": "Nov 13, 2010 ... Work: Fidelity Investments, Fidelity National Asset Management Solutions Inc ... \nRelated to: Floyd Dixon, Brittany Dixon, Kelley Duvernay, Christopher Dixon ... \nWork: Mote Marine Laboratory, Museum of The Everglades.",
#    "htmlSnippet": "Nov 13, 2010 \u003cb\u003e...\u003c/b\u003e Work: Fidelity Investments, Fidelity National \u003cb\u003eAsset\u003c/b\u003e Management Solutions Inc ... \u003cbr\u003e\nRelated to: Floyd Dixon, Brittany Dixon, \u003cb\u003eKelley\u003c/b\u003e Duvernay, Christopher Dixon ... \u003cbr\u003e\nWork: \u003cb\u003eMote\u003c/b\u003e Marine Laboratory, Museum of The Everglades.",
#    "formattedUrl": "radaris.com/p/Kellie/Dixon/",
#    "htmlFormattedUrl": "radaris.com/p/Kellie/Dixon/",
#    "pagemap": {
#     "cse_image": [
#      {
#       "src": "http://radaris.com/p/Kellie/Dixon/us-map.png"
#      }
#     ],
#     "person": [
#      {
#       "location": "Niagara Falls NY"
#      },
#      {
#       "url": "Kellie M Mccarthy",
#       "name": "Kellie M Mccarthy",
#       "givenname": "Kellie",
#       "additionalname": "M",
#       "familyname": "Mccarthy"
#      },
#      {
#       "url": "Kevin Mccarthy, 61",
#       "name": "Kevin Mccarthy, 61",
#       "givenname": "Kevin",
#       "familyname": "Mccarthy"
#      },
#      {
#       "url": "Mary Mccarthy, 97",
#       "name": "Mary Mccarthy, 97",
#       "givenname": "Mary",
#       "familyname": "Mccarthy"
#      },
#      {
#       "url": "Mickie Mccarthy, 57",
#       "name": "Mickie Mccarthy, 57",
#       "givenname": "Mickie",
#       "familyname": "Mccarthy"
#      },
#      {
#       "url": "Kellie S Pierre",
#       "name": "Kellie S Pierre",
#       "givenname": "Kellie",
#       "additionalname": "S",
#       "familyname": "Pierre"
#      },
#      {
#       "url": "Debbie Stpierre",
#       "name": "Debbie Stpierre",
#       "givenname": "Debbie",
#       "familyname": "Stpierre"
#      },
#      {
#       "url": "Debra Stpierre",
#       "name": "Debra Stpierre",
#       "givenname": "Debra",
#       "familyname": "Stpierre"
#      },
#      {
#       "url": "Kellie Stpierre, 50",
#       "name": "Kellie Stpierre, 50",
#       "givenname": "Kellie",
#       "familyname": "Stpierre"
#      },
#      {
#       "url": "Kellie A Woolworth",
#       "name": "Kellie A Woolworth",
#       "givenname": "Kellie",
#       "additionalname": "A",
#       "familyname": "Woolworth"
#      },
#      {
#       "url": "Belinda Johnson, 52",
#       "name": "Belinda Johnson, 52",
#       "givenname": "Belinda",
#       "familyname": "Johnson"
#      },
#      {
#       "url": "Sally Whittaker, 65",
#       "name": "Sally Whittaker, 65",
#       "givenname": "Sally",
#       "familyname": "Whittaker"
#      },
#      {
#       "url": "Dana Waters, 43",
#       "name": "Dana Waters, 43",
#       "givenname": "Dana",
#       "familyname": "Waters"
#      },
#      {
#       "url": "Keiler G Baker-Dixon",
#       "name": "Keiler G Baker-Dixon",
#       "givenname": "Keiler",
#       "additionalname": "G",
#       "familyname": "Baker-Dixon"
#      },
#      {
#       "url": "Camilla Malone, -10",
#       "name": "Camilla Malone, -10",
#       "givenname": "Camilla",
#       "familyname": "Malone"
#      },
#      {
#       "url": "Keilier Williams, 29",
#       "name": "Keilier Williams, 29",
#       "givenname": "Keilier",
#       "familyname": "Williams"
#      },
#      {
#       "url": "Mary Reeves",
#       "name": "Mary Reeves",
#       "givenname": "Mary",
#       "familyname": "Reeves"
#      },
#      {
#       "url": "Kelli E Carr",
#       "name": "Kelli E Carr",
#       "givenname": "Kelli",
#       "additionalname": "E",
#       "familyname": "Carr"
#      },
#      {
#       "url": "Laura Dixon",
#       "name": "Laura Dixon",
#       "givenname": "Laura",
#       "familyname": "Dixon"
#      },
#      {
#       "url": "Stevens Dixon, 53",
#       "name": "Stevens Dixon, 53",
#       "givenname": "Stevens",
#       "familyname": "Dixon"
#      },
#      {
#       "url": "William Dixon, 63",
#       "name": "William Dixon, 63",
#       "givenname": "William",
#       "familyname": "Dixon"
#      },
#      {
#       "url": "Kellie L Duvernay",
#       "name": "Kellie L Duvernay",
#       "givenname": "Kellie",
#       "additionalname": "L",
#       "familyname": "Duvernay"
#      },
#      {
#       "url": "Floyd Dixon, 56",
#       "name": "Floyd Dixon, 56",
#       "givenname": "Floyd",
#       "familyname": "Dixon"
#      },
#      {
#       "url": "Gloria Dixon, 76",
#       "name": "Gloria Dixon, 76",
#       "givenname": "Gloria",
#       "familyname": "Dixon"
#      },
#      {
#       "url": "John Dixon, 57",
#       "name": "John Dixon, 57",
#       "givenname": "John",
#       "familyname": "Dixon"
#      },
#      {
#       "url": "Vickie Dixon",
#       "name": "Vickie Dixon",
#       "givenname": "Vickie",
#       "familyname": "Dixon"
#      },
#      {
#       "url": "G K Baker",
#       "name": "G K Baker",
#       "givenname": "G",
#       "additionalname": "K",
#       "familyname": "Baker"
#      },
#      {
#       "url": "Camilla Malone, -10",
#       "name": "Camilla Malone, -10",
#       "givenname": "Camilla",
#       "familyname": "Malone"
#      },
#      {
#       "url": "Keilier Williams, 29",
#       "name": "Keilier Williams, 29",
#       "givenname": "Keilier",
#       "familyname": "Williams"
#      },
#      {
#       "url": "Keilier Dixon, 29",
#       "name": "Keilier Dixon, 29",
#       "givenname": "Keilier",
#       "familyname": "Dixon"
#      },
#      {
#       "url": "G K Baker",
#       "name": "G K Baker",
#       "givenname": "G",
#       "additionalname": "K",
#       "familyname": "Baker"
#      },
#      {
#       "url": "Camilla Malone, -10",
#       "name": "Camilla Malone, -10",
#       "givenname": "Camilla",
#       "familyname": "Malone"
#      },
#      {
#       "url": "Keilier Williams, 29",
#       "name": "Keilier Williams, 29",
#       "givenname": "Keilier",
#       "familyname": "Williams"
#      },
#      {
#       "url": "Keilier Dixon, 29",
#       "name": "Keilier Dixon, 29",
#       "givenname": "Keilier",
#       "familyname": "Dixon"
#      },
#      {
#       "url": "Kellie A Mabe",
#       "name": "Kellie A Mabe",
#       "givenname": "Kellie",
#       "additionalname": "A",
#       "familyname": "Mabe"
#      },
#      {
#       "url": "Catherine Mckenzie, 47",
#       "name": "Catherine Mckenzie, 47",
#       "givenname": "Catherine",
#       "familyname": "Mckenzie"
#      },
#      {
#       "url": "Edward Stutz, 35",
#       "name": "Edward Stutz, 35",
#       "givenname": "Edward",
#       "familyname": "Stutz"
#      },
#      {
#       "url": "Edward Stutz, 60",
#       "name": "Edward Stutz, 60",
#       "givenname": "Edward",
#       "familyname": "Stutz"
#      },
#      {
#       "url": "Kellie M Cooper",
#       "name": "Kellie M Cooper",
#       "givenname": "Kellie",
#       "additionalname": "M",
#       "familyname": "Cooper"
#      },
#      {
#       "url": "Deborah Dixon, 55",
#       "name": "Deborah Dixon, 55",
#       "givenname": "Deborah",
#       "familyname": "Dixon"
#      },
#      {
#       "url": "Lois Dixon, 84",
#       "name": "Lois Dixon, 84",
#       "givenname": "Lois",
#       "familyname": "Dixon"
#      },
#      {
#       "url": "Patrick Dixon, 57",
#       "name": "Patrick Dixon, 57",
#       "givenname": "Patrick",
#       "familyname": "Dixon"
#      }
#     ],
#     "cse_thumbnail": [
#      {
#       "width": "289",
#       "height": "174",
#       "src": "https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcQ72-3HZJ_jG8CoSCbGargSlyxfqIqKnHF6IFRJBkoHryypQnTxQrl9fkpY"
#      }
#     ],
#     "postaladdress": [
#      {
#       "addresslocality": "Niagara Falls",
#       "addressregion": "NY"
#      },
#      {
#       "addresslocality": "Danbury",
#       "addressregion": "CT"
#      },
#      {
#       "addresslocality": "Northville",
#       "addressregion": "MI"
#      },
#      {
#       "addresslocality": "Port Saint Lucie",
#       "addressregion": "FL"
#      },
#      {
#       "addresslocality": "Hollywood",
#       "addressregion": "FL"
#      },
#      {
#       "addresslocality": "Los Angeles",
#       "addressregion": "CA"
#      },
#      {
#       "addresslocality": "Fort Pierce",
#       "addressregion": "FL"
#      },
#      {
#       "addresslocality": "Fort Pierce",
#       "addressregion": "FL"
#      },
#      {
#       "addresslocality": "Saint Johns",
#       "addressregion": "MI"
#      },
#      {
#       "addresslocality": "Seattle",
#       "addressregion": "WA"
#      }
#     ],
#     "Breadcrumb": [
#      {
#       "title": "People Search",
#       "url": "People Search"
#      },
#      {
#       "title": "Kellie Dixon",
#       "url": "Kellie Dixon"
#      }
#     ],
#     "metatags": [
#      {
#       "twitter:description": "I just found address, phone, and public records for Kellie Dixon on Radaris",
#       "og:title": "Find Kellie Dixon in US",
#       "og:site_name": "radaris.com",
#       "og:description": "See states where people with name Kellie Dixon live in US",
#       "og:image": "http://radaris.com/p/Kellie/Dixon/us-map.png"
#      }
#     ],
#     "hcard": [
#      {
#       "fn": "Kellie M Mccarthy",
#       "url": "http://radaris.com/~Kellie-Mccarthy/152305750"
#      },
#      {
#       "fn": "Kellie S Pierre",
#       "url": "http://radaris.com/~Kellie-Pierre/163229631"
#      },
#      {
#       "fn": "Kellie A Woolworth",
#       "url": "http://radaris.com/~Kellie-Woolworth/180367403"
#      },
#      {
#       "fn": "Keiler G Baker-Dixon",
#       "url": "http://radaris.com/~Keiler-Baker-Dixon/205805413"
#      },
#      {
#       "fn": "Kelli E Carr",
#       "url": "http://radaris.com/~Kelli-Carr/242819934"
#      },
#      {
#       "fn": "Kellie L Duvernay",
#       "url": "http://radaris.com/~Kellie-Duvernay/253084378"
#      },
#      {
#       "fn": "G K Baker",
#       "url": "http://radaris.com/~G-Baker/369690919"
#      },
#      {
#       "fn": "G K Baker",
#       "url": "http://radaris.com/~G-Baker/423316559"
#      },
#      {
#       "fn": "Kellie A Mabe",
#       "url": "http://radaris.com/~Kellie-Mabe/139021888"
#      },
#      {
#       "fn": "Kellie M Cooper",
#       "url": "http://radaris.com/~Kellie-Cooper/144902534"
#      }
#     ]
#    }
#   }
#  ]
# }

# %% [markdown]
# ** Output from the First Result**
#
# Here we can see that the first result includes 0 total results. It looks like
# we have some generic fields that seem to be search meta-data. This initially
# looks like it would be 3 elasticsearch documents but it may make more sense
# to condense the meta-data into one ES document.
#
# Let's take a look at results that include search results next

# %%
# result that contains search hits
import codecs

print("key:\n {}\n".format(results.keys()[1]))
print("value:\n {}".format(codecs.encode(results[results.keys()[1]],'ascii','ignore')))
# Out:
# key:
#  11111157
#
# value:
#  {
#  "kind": "customsearch#search",
#  "url": {
#   "type": "application/json",
#   "template": "https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&cref={cref?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json"
#  },
#  "queries": {
#   "nextPage": [
#    {
#     "title": "Google Custom Search - Al Krueger",
#     "totalResults": "2530",
#     "searchTerms": "Al Krueger",
#     "count": 10,
#     "startIndex": 11,
#     "language": "lang_en",
#     "inputEncoding": "utf8",
#     "outputEncoding": "utf8",
#     "safe": "off",
#     "cx": "003891126258438650518:fcb7zxrqavu",
#     "filter": "1",
#     "exactTerms": "asset",
#     "dateRestrict": "'2012'"
#    }
#   ],
#   "request": [
#    {
#     "title": "Google Custom Search - Al Krueger",
#     "totalResults": "2530",
#     "searchTerms": "Al Krueger",
#     "count": 10,
#     "startIndex": 1,
#     "language": "lang_en",
#     "inputEncoding": "utf8",
#     "outputEncoding": "utf8",
#     "safe": "off",
#     "cx": "003891126258438650518:fcb7zxrqavu",
#     "filter": "1",
#     "exactTerms": "asset",
#     "dateRestrict": "'2012'"
#    }
#   ]
#  },
#  "context": {
#   "title": "greencall"
#  },
#  "searchInformation": {
#   "searchTime": 0.447709,
#   "formattedSearchTime": "0.45",
#   "totalResults": "2530",
#   "formattedTotalResults": "2,530"
#  },
#  "items": [
#   {
#    "kind": "customsearch#result",
#    "title": "The scariest nightmares do not always involve Freddie Krueger",
#    "htmlTitle": "The scariest nightmares do not always involve Freddie \u003cb\u003eKrueger\u003c/b\u003e",
#    "link": "http://estateplan-al.com/lawyer/2014/06/12/Elder-Law/Nightmare-in-Dothan--(The-scariest-nightmares-do-not-always-involve-Freddie-Krueger)_bl13857.htm",
#    "displayLink": "estateplan-al.com",
#    "snippet": "Jun 12, 2014 ... Now if you ask a Medicaid office how much the wife could keep they will tell you \n$50,000 because Alabama law says the spouse of a nursing...",
#    "htmlSnippet": "Jun 12, 2014 \u003cb\u003e...\u003c/b\u003e Now if you ask a Medicaid office how much the wife could keep they will tell you \u003cbr\u003e\n$50,000 because \u003cb\u003eAlabama\u003c/b\u003e law says the spouse of a nursing&nbsp;...",
#    "cacheId": "1W0OB-LMT00J",
#    "formattedUrl": "estateplan-al.com/.../Nightmare-in-Dothan--(The-scariest-nightmares-do-not- always-involve-Freddie-Krueger)_bl13857.htm",
#    "htmlFormattedUrl": "estateplan-\u003cb\u003eal\u003c/b\u003e.com/.../Nightmare-in-Dothan--(The-scariest-nightmares-do-not- always-involve-Freddie-\u003cb\u003eKrueger\u003c/b\u003e)_bl13857.htm",
#    "pagemap": {
#     "cse_image": [
#      {
#       "src": "http://estateplan-al.com/global_pictures/FreddieKrueger90398755.jpg"
#      }
#     ],
#     "cse_thumbnail": [
#      {
#       "width": "160",
#       "height": "196",
#       "src": "https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcSNskElqoU_NmFwg5rt2CFAFahJBAA4tUriPSXyE4ssIGOJfqtvbbxZpkE"
#      }
#     ],
#     "postaladdress": [
#      {
#       "streetaddress": "2000 Providence Park, Suite 200",
#       "addresslocality": "Birmingham",
#       "addressregion": "AL",
#       "postalcode": "35242"
#      }
#     ],
#     "attorney": [
#      {
#       "legalname": "Bailey Law Firm",
#       "telephone": "Phone: 205-263-5060"
#      }
#     ],
#     "metatags": [
#      {
#       "og:title": "Nightmare in Dothan  (The scariest nightmares do not always involve Freddie Krueger) | Bailey Law Firm Estate Planning Blog",
#       "og:type": "website",
#       "og:url": "http://estateplan-al.com/lawyer/2014/06/12/Elder-Law/Nightmare-in-Dothan--(The-scariest-nightmares-do-not-always-involve-Freddie-Krueger)_bl13857.htm",
#       "og:image": "http://estateplan-al.com/global_pictures/FreddieKrueger90398755.jpg",
#       "og:site_name": "estateplan-al.com"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Jack H Krueger Birmingham AL, 35242  Manta.com",
#    "htmlTitle": "Jack H \u003cb\u003eKrueger\u003c/b\u003e Birmingham \u003cb\u003eAL\u003c/b\u003e, 35242  Manta.com",
#    "link": "http://www.manta.com/c/mbnr3g3/jack-h-krueger",
#    "displayLink": "www.manta.com",
#    "snippet": "... services, phone numbers, and reviews on Jack H Krueger in Birmingham, AL. \n... A privately held company in Birmingham, AL. ... 1 Asset Management",
#    "htmlSnippet": "... services, phone numbers, and reviews on Jack H \u003cb\u003eKrueger\u003c/b\u003e in Birmingham, \u003cb\u003eAL\u003c/b\u003e. \u003cbr\u003e\n... A privately held company in Birmingham, \u003cb\u003eAL\u003c/b\u003e. ... 1 \u003cb\u003eAsset\u003c/b\u003e Management",
#    "cacheId": "Y5F7l1qzgRcJ",
#    "formattedUrl": "www.manta.com/c/mbnr3g3/jack-h-krueger",
#    "htmlFormattedUrl": "www.manta.com/c/mbnr3g3/jack-h-\u003cb\u003ekrueger\u003c/b\u003e",
#    "pagemap": {
#     "cse_image": [
#      {
#       "src": "//cc3.manta-r3.com/assets-gz/fa2cf7c/img/mlogo_opengraph.gif"
#      }
#     ],
#     "postaladdress": [
#      {
#       "streetaddress": "10 Inverness Center Parkway",
#       "addresslocality": "Birmingham",
#       "addressregion": "AL",
#       "postalcode": "35242"
#      }
#     ],
#     "geocoordinates": [
#      {
#       "latitude": "33.424244",
#       "longitude": "-86.703431"
#      }
#     ],
#     "localbusiness": [
#      {
#       "name": "Jack H Krueger",
#       "telephone": "Phone: (205) 991-1050",
#       "description": "Categorized under Financial Advisory Services. Current estimates show this company has an annual revenue of $2.5 to 5 million and employs a staff of approximately 5 to 9.",
#       "isicv4": "6282",
#       "naics": "52393002"
#      }
#     ],
#     "metatags": [
#      {
#       "language": "english",
#       "viewport": "width=device-width, initial-scale=1.0",
#       "og:site_name": "Manta",
#       "og:type": "company",
#       "og:url": "http://www.manta.com/c/mbnr3g3/jack-h-krueger",
#       "og:title": "Jack H Krueger",
#       "og:description": "Financial Advisory Services in Birmingham, AL",
#       "og:image": "//cc3.manta-r3.com/assets-gz/fa2cf7c/img/mlogo_opengraph.gif"
#      }
#     ],
#     "breadcrumb": [
#      {
#       "url": "U.S.",
#       "title": "U.S."
#      },
#      {
#       "url": "Birmingham, AL",
#       "title": "Birmingham, AL"
#      },
#      {
#       "url": "Financial",
#       "title": "Financial"
#      },
#      {
#       "url": "Investment Advice",
#       "title": "Investment Advice"
#      },
#      {
#       "url": "Financial Advisory Services",
#       "title": "Financial Advisory Services"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Do Single Member LLC's Provide Asset Protection? | Bailey Law ...",
#    "htmlTitle": "Do Single Member LLC&#39;s Provide \u003cb\u003eAsset\u003c/b\u003e Protection? | Bailey Law \u003cb\u003e...\u003c/b\u003e",
#    "link": "http://estateplan-al.com/lawyer/2014/11/24/Business-Planning/Do-Single-Member-LLCs-Provide-Asset-Protection_bl15912.htm",
#    "displayLink": "estateplan-al.com",
#    "snippet": "Nov 24, 2014 ... Generally, single member LLCs provide personal asset protection to their .... \nLocated in Birmingham, AL the attorneys of Bailey Estate Planning...",
#    "htmlSnippet": "Nov 24, 2014 \u003cb\u003e...\u003c/b\u003e Generally, single member LLCs provide personal \u003cb\u003easset\u003c/b\u003e protection to their .... \u003cbr\u003e\nLocated in Birmingham, \u003cb\u003eAL\u003c/b\u003e the attorneys of Bailey Estate Planning&nbsp;...",
#    "cacheId": "-WnC8qr-6ssJ",
#    "formattedUrl": "estateplan-al.com/.../Do-Single-Member-LLCs-Provide-Asset-Protection_ bl15912.htm",
#    "htmlFormattedUrl": "estateplan-\u003cb\u003eal\u003c/b\u003e.com/.../Do-Single-Member-LLCs-Provide-\u003cb\u003eAsset\u003c/b\u003e-Protection_ bl15912.htm",
#    "pagemap": {
#     "cse_image": [
#      {
#       "src": "http://estateplan-al.com/lawyer/2014/11/global_pictures/Defaults/NewsletterTemplates/Do-Single-Member-LLCs-Provi8746.png"
#      }
#     ],
#     "cse_thumbnail": [
#      {
#       "width": "160",
#       "height": "143",
#       "src": "https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcTjUcp0Cdec_adVhYrkDGrhMdl664Fn_V-Qrecvf6ugsrm-cabO-hfFRHe5"
#      }
#     ],
#     "postaladdress": [
#      {
#       "streetaddress": "2000 Providence Park, Suite 200",
#       "addresslocality": "Birmingham",
#       "addressregion": "AL",
#       "postalcode": "35242"
#      }
#     ],
#     "attorney": [
#      {
#       "legalname": "Bailey Law Firm",
#       "telephone": "Phone: 205-263-5060"
#      }
#     ],
#     "metatags": [
#      {
#       "og:title": "Do Single Member LLC's Provide Asset Protection? | Bailey Law Firm Estate Planning Blog",
#       "og:type": "website",
#       "og:url": "http://estateplan-al.com/lawyer/2014/11/24/Business-Planning/Do-Single-Member-LLCs-Provide-Asset-Protection_bl15912.htm",
#       "og:image": "http://estateplan-al.com/global_pictures/Do-Single-Member-LLCs-Provi8746.png",
#       "og:site_name": "estateplan-al.com"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Client Testimonials - Krueger & Hernandez SC",
#    "htmlTitle": "Client Testimonials - \u003cb\u003eKrueger\u003c/b\u003e &amp; Hernandez SC",
#    "link": "http://www.kh-law.net/our-firm/client-testimonials/",
#    "displayLink": "www.kh-law.net",
#    "snippet": "A.L.. Thanks so much for your help. As always all of you guys (gals) are FIRST \nCLASS! -B.F. & K.F.. To the entire KH Staff, Thank you so very much for your...",
#    "htmlSnippet": "\u003cb\u003eA.L.\u003c/b\u003e. Thanks so much for your help. As always all of you guys (gals) are FIRST \u003cbr\u003e\nCLASS! -B.F. &amp; K.F.. To the entire KH Staff, Thank you so very much for your&nbsp;...",
#    "cacheId": "hfa6KhhskpgJ",
#    "formattedUrl": "www.kh-law.net/our-firm/client-testimonials/",
#    "htmlFormattedUrl": "www.kh-law.net/our-firm/client-testimonials/",
#    "pagemap": {
#     "postaladdress": [
#      {
#       "streetaddress": "One Financial Place 8215 Greenway Blvd, Ste. 590",
#       "addresslocality": "Middleton",
#       "addressregion": "WI",
#       "postalcode": "53562"
#      },
#      {
#       "streetaddress": "Second Street Professional Offices 123 Second Street, P.O. Box 41",
#       "addresslocality": "Baraboo",
#       "addressregion": "WI",
#       "postalcode": "53913"
#      },
#      {
#       "streetaddress": "One Magnificent Mile 980 N. Michigan Ave, Ste. 1400",
#       "addresslocality": "Chicago",
#       "addressregion": "IL",
#       "postalcode": "60611"
#      },
#      {
#       "streetaddress": "590 Madison Avenue",
#       "addresslocality": "New York City",
#       "postalcode": "10022",
#       "addresscountry": "United States"
#      }
#     ],
#     "attorney": [
#      {
#       "name": "MIDDLETON",
#       "faxnumber": "(608) 824-9140"
#      },
#      {
#       "name": "BARABOO",
#       "faxnumber": "(608) 356-2008"
#      },
#      {
#       "name": "*CHICAGO*"
#      },
#      {
#       "name": "*NEW YORK*"
#      }
#     ],
#     "metatags": [
#      {
#       "viewport": "width=device-width, initial-scale=1",
#       "og:locale": "en_US",
#       "og:type": "article",
#       "og:title": "Client Testimonials - Krueger & Hernandez SC",
#       "og:description": "KH Team Tricia, Thank you for keeping me up with what's going with your monthly newsletter. I really like it! -T.L. The endorsed seminar you gave last",
#       "og:url": "http://www.kh-law.net/our-firm/client-testimonials/",
#       "og:site_name": "Krueger & Hernandez SC",
#       "article:published_time": "2012-05-03T17:01:32+00:00",
#       "article:modified_time": "2015-03-18T20:57:02+00:00",
#       "og:updated_time": "2015-03-18T20:57:02+00:00"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Estate Planning: The Medicaid Asset Protection Trust | Bailey Law ...",
#    "htmlTitle": "Estate Planning: The Medicaid \u003cb\u003eAsset\u003c/b\u003e Protection Trust | Bailey Law \u003cb\u003e...\u003c/b\u003e",
#    "link": "http://estateplan-al.com/lawyer/2014/09/30/Elder-Law/Estate-Planning-The-Medicaid-Asset-Protection-Trust_bl15735.htm",
#    "displayLink": "estateplan-al.com",
#    "snippet": "Sep 30, 2014 ... The irrevocable Medicaid Asset Protection Trust has proven to be a .... Located in \nBirmingham, AL the attorneys of Bailey Estate Planning...",
#    "htmlSnippet": "Sep 30, 2014 \u003cb\u003e...\u003c/b\u003e The irrevocable Medicaid \u003cb\u003eAsset\u003c/b\u003e Protection Trust has proven to be a .... Located in \u003cbr\u003e\nBirmingham, \u003cb\u003eAL\u003c/b\u003e the attorneys of Bailey Estate Planning&nbsp;...",
#    "cacheId": "WClQZaY0vCkJ",
#    "formattedUrl": "estateplan-al.com/.../Estate-Planning-The-Medicaid-Asset-Protection-Trust_ bl15735.htm",
#    "htmlFormattedUrl": "estateplan-\u003cb\u003eal\u003c/b\u003e.com/.../Estate-Planning-The-Medicaid-\u003cb\u003eAsset\u003c/b\u003e-Protection-Trust_ bl15735.htm",
#    "pagemap": {
#     "cse_image": [
#      {
#       "src": "https://www.amicuscreative.com/global_pictures/Defaults/NewsletterTemplates/rsz_medicaidtrusts7077.jpg"
#      }
#     ],
#     "postaladdress": [
#      {
#       "streetaddress": "2000 Providence Park, Suite 200",
#       "addresslocality": "Birmingham",
#       "addressregion": "AL",
#       "postalcode": "35242"
#      }
#     ],
#     "attorney": [
#      {
#       "legalname": "Bailey Law Firm",
#       "telephone": "Phone: 205-263-5060"
#      }
#     ],
#     "metatags": [
#      {
#       "og:title": "Estate Planning: The Medicaid Asset Protection Trust | Bailey Law Firm Estate Planning Blog",
#       "og:type": "website",
#       "og:url": "http://estateplan-al.com/lawyer/2014/09/30/Elder-Law/Estate-Planning-The-Medicaid-Asset-Protection-Trust_bl15735.htm",
#       "og:image": "https://www.amicuscreative.com/global_pictures/Defaults/NewsletterTemplates/rsz_medicaidtrusts7077.jpg",
#       "og:site_name": "estateplan-al.com"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Allied Reliability Group | LinkedIn",
#    "htmlTitle": "Allied Reliability Group | LinkedIn",
#    "link": "https://www.linkedin.com/company/allied-reliability",
#    "displayLink": "www.linkedin.com",
#    "snippet": "Jon Krueger, Ali Al-Saleh +2 ... maintenance plans, and vetted work procedures \nacross asset classes, component classes and parts! http://bit.ly/1R4unSR.",
#    "htmlSnippet": "Jon \u003cb\u003eKrueger\u003c/b\u003e, Ali \u003cb\u003eAl\u003c/b\u003e-Saleh +2 ... maintenance plans, and vetted work procedures \u003cbr\u003e\nacross \u003cb\u003easset\u003c/b\u003e classes, component classes and parts! http://bit.ly/1R4unSR.",
#    "cacheId": "YSEeKPnAlbcJ",
#    "formattedUrl": "https://www.linkedin.com/company/allied-reliability",
#    "htmlFormattedUrl": "https://www.linkedin.com/company/allied-reliability",
#    "pagemap": {
#     "cse_image": [
#      {
#       "src": "https://media.licdn.com/mpr/mpr/shrink_200_100/AAEAAQAAAAAAAALDAAAAJDA0MGRhYTFmLTBiZGQtNDRiZS1iMzI5LTg5YmE5NjA1MWFkMw.png"
#      }
#     ],
#     "cse_thumbnail": [
#      {
#       "width": "160",
#       "height": "80",
#       "src": "https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcRBfJr6ZQCzAQAZ1rc00Bx7jkNhx4LDvzAYGWDFS5QYsJcfd1S2Fvhq6w"
#      }
#     ],
#     "postaladdress": [
#      {
#       "streetaddress": "4200 Faber Place Drive",
#       "addresslocality": "Charleston,",
#       "addressregion": "SC",
#       "postalcode": "29405",
#       "addresscountry": "United States"
#      }
#     ],
#     "metatags": [
#      {
#       "globaltrackingurl": "//www.linkedin.com/mob/tracking",
#       "globaltrackingappname": "biz",
#       "globaltrackingappid": "webTracking",
#       "lnkd-track-json-lib": "https://static.licdn.com/scds/concat/common/js?v=build-2000_8_48953-prod&f=lib%2Fjson%2Fjson2&f=lib%2Ferror-tracking%2F1.0.0%2Fshared%2Fxhr.min&fc=2",
#       "treeid": "i4evNxBc7xNAxDiAzCoAAA==",
#       "appname": "biz",
#       "pageimpressionid": "8d9bbeff-dcb2-4611-9053-769bf1a065cf",
#       "pagekey": "biz-overview-company-public",
#       "analyticsurl": "/analytics/noauthtracker",
#       "msapplication-tileimage": "https://static.licdn.com/scds/common/u/images/logos/linkedin/logo-in-win8-tile-144_v1.png",
#       "msapplication-tilecolor": "#0077B5",
#       "application-name": "LinkedIn",
#       "remote-nav-init-marker": "true",
#       "og:image": "https://media.licdn.com/mpr/mpr/shrink_200_100/AAEAAQAAAAAAAALDAAAAJDA0MGRhYTFmLTBiZGQtNDRiZS1iMzI5LTg5YmE5NjA1MWFkMw.png",
#       "og:description": "Reliability its in our DNA.    Allied Reliability Group offers best-in-industry maintenance, reliability, and operational consulting and services, training, staffing, and integrated software solutions servicing the industrial and manufacturing sector.    Our Vision Statement  Be the global partner for operational reliability solutions.    Our Mission Statement  For our customers, employees, and shareholders, we will:   Understand each and their needs    Deliver superior technical capabilities    Demonstrate increasing value    Our Locations:    Allied Reliability Group Global Headquarters    4200 Faber Place Drive  Charleston, SC 29405  Phone: +1.843.414.5760  Fax: +1 843.414.5779  E-mail: info@alliedreliability.com       Allied Reliability Group EMEA    Interleuvenlaan 64  3001 Heverlee, Belgium  Phone: +32 (0)16 40 01 36  Fax: +32 (0)16 40 01 37  E-mail: info_emea@alliedreliability.com    Allied Reliability Group Canada    2572 Daniel Johnson, 2nd Floor  Laval, QC, Canada  H7T 2R3  Phone: +1.",
#       "og:type": "article",
#       "og:title": "Allied Reliability Group",
#       "og:url": "http://www.linkedin.com/company/allied-reliability"
#      }
#     ],
#     "corporation": [
#      {
#       "name": "Allied Reliability Group"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Biology 352 \u003e Krueger \u003e Notes \u003e 354obesity_trends_2014pp.ppt ...",
#    "htmlTitle": "Biology 352 &gt; \u003cb\u003eKrueger\u003c/b\u003e &gt; Notes &gt; 354obesity_trends_2014pp.ppt \u003cb\u003e...\u003c/b\u003e",
#    "link": "https://www.studyblue.com/notes/note/n/354obesity_trends_2014ppppt/file/11180936",
#    "displayLink": "www.studyblue.com",
#    "snippet": "May 11, 2014 ... Find and study online flashcards from Biology 352. Visit StudyBlue today to learn \nmore!",
#    "htmlSnippet": "May 11, 2014 \u003cb\u003e...\u003c/b\u003e Find and study online flashcards from Biology 352. Visit StudyBlue today to learn \u003cbr\u003e\nmore!",
#    "cacheId": "ZVGw5saL3N4J",
#    "formattedUrl": "https://www.studyblue.com/notes/note/n/354obesity.../11180936",
#    "htmlFormattedUrl": "https://www.studyblue.com/notes/note/n/354obesity.../11180936",
#    "pagemap": {
#     "cse_image": [
#      {
#       "src": "https://classconnection.s3.amazonaws.com/b1be2871/19697/files/7f36cefd32285dfff13e7a17000a22be/blur/preview0.jpg"
#      }
#     ],
#     "person": [
#      {
#       "name": "Krueger"
#      }
#     ],
#     "cse_thumbnail": [
#      {
#       "width": "275",
#       "height": "183",
#       "src": "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSn3-z6-hnwWxk4s3ip8UJRTuOpc49Ak2ej-4mZrLFdDkPFwPhFldCihFF5"
#      }
#     ],
#     "postaladdress": [
#      {
#       "addressregion": "Wisconsin"
#      }
#     ],
#     "creativework": [
#      {
#       "name": "354obesity_trends_2014pp.ppt"
#      },
#      {
#       "author": "Jared F.",
#       "datecreated": "2014-05-11",
#       "datemodified": "2014-05-11",
#       "interactioncount": "2"
#      },
#      {
#       "text": "Weight control Complex Easy for some; not for others Genes; prenatal environment; childhood; lifestyle; exercise; foods and portions; habits; knowledge; sleep patterns; occupation; leisure..."
#      }
#     ],
#     "collegeoruniversity": [
#      {
#       "name": "University of Wisconsin - Eau Claire"
#      }
#     ],
#     "metatags": [
#      {
#       "fb:app_id": "102540830008",
#       "viewport": "width=device-width, initial-scale=1.0, maximum-scale=1.0",
#       "apple-itunes-app": "app-id=323887414, app-argument=studyblue://study?docID=11180936&docType=1&docSubType=0",
#       "og:title": "Biology 352 \u003e Krueger \u003e Notes \u003e 354obesity_trends_2014pp.ppt | StudyBlue",
#       "og:type": "studyblue:deck",
#       "og:url": "https://www.studyblue.com/notes/note/n/354obesity_trends_2014ppppt/file/11180936",
#       "og:description": "Find and study online flashcards from Biology 352. Visit StudyBlue today to learn more!",
#       "og:image": "https://classconnection.s3.amazonaws.com/images/fb-og-deck.png",
#       "studyblue:created": "2014-05-11",
#       "og:site_name": "StudyBlue",
#       "twitter:image:src": "https://classconnection.s3.amazonaws.com/images/fb-og-deck.png",
#       "twitter:card": "summary",
#       "twitter:site": "@studyblue",
#       "twitter:title": "Biology 352 \u003e Krueger \u003e Notes \u003e 354obesity_trends_2014pp.ppt | StudyBlue",
#       "twitter:description": "Find and study online flashcards from Biology 352. Visit StudyBlue today to learn more!"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Accounting Jobs, Employment in Greenville, SC | Indeed.com",
#    "htmlTitle": "Accounting Jobs, Employment in Greenville, SC | Indeed.com",
#    "link": "http://www.indeed.com/q-Accounting-l-Greenville,-SC-jobs.html",
#    "displayLink": "www.indeed.com",
#    "snippet": "Jobs 1 - 10 of 402 ... Fixed Asset Accountant. Randstad Professionals 8 reviews - Greer, SC. 4-year \ndegree in accounting or related field or equivalent experience,...",
#    "htmlSnippet": "Jobs 1 - 10 of 402 \u003cb\u003e...\u003c/b\u003e Fixed \u003cb\u003eAsset\u003c/b\u003e Accountant. Randstad Professionals 8 reviews - Greer, SC. 4-year \u003cbr\u003e\ndegree in accounting or related field or equivalent experience,&nbsp;...",
#    "cacheId": "JJetLrjxzsoJ",
#    "formattedUrl": "www.indeed.com/q-Accounting-l-Greenville,-SC-jobs.html",
#    "htmlFormattedUrl": "www.indeed.com/q-Accounting-l-Greenville,-SC-jobs.html",
#    "pagemap": {
#     "postaladdress": [
#      {
#       "addresslocality": "Greenville, SC"
#      },
#      {
#       "addresslocality": "Greenville County, SC"
#      },
#      {
#       "addresslocality": "Greenville, SC"
#      },
#      {
#       "addresslocality": "Greenville, SC"
#      },
#      {
#       "addresslocality": "Greenville, SC"
#      },
#      {
#       "addresslocality": "Simpsonville, SC"
#      },
#      {
#       "addresslocality": "Greenville, SC"
#      },
#      {
#       "addresslocality": "Greenville, SC"
#      },
#      {
#       "addresslocality": "Greenville, SC"
#      },
#      {
#       "addresslocality": "Greenville, SC"
#      }
#     ],
#     "jobposting": [
#      {
#       "title": "FINANCIAL ANALYST LEAD Job",
#       "hiringorganization": "Bon Secours Health System",
#       "name": "Bon Secours Health System",
#       "description": "Director of Accounting, Finance and Reimbursement, as well as the Accounting Manager, on more complex projects and investigatory and/or other analytical..."
#      },
#      {
#       "title": "Administrative Specialist II/Customer Service Representative...",
#       "hiringorganization": "State of South Carolina",
#       "name": "State of South Carolina",
#       "description": "Manages and maintains transaction payments via cash, credit card, check or money order. Original, duplicate, transfers, temporary and replacement vehicle..."
#      },
#      {
#       "title": "Investor Accountant I",
#       "hiringorganization": "Shellpoint Mortgage Servicing",
#       "name": "Shellpoint Mortgage Servicing",
#       "description": "Extensive knowledge of accounting reconciliations. Leads Accounting, Treasury Operations and related mortgage operations in decisions related to the creation..."
#      },
#      {
#       "title": "Account Specialist",
#       "hiringorganization": "Greenville Health System",
#       "name": "Greenville Health System",
#       "description": "Coordinates collections and delinquent unpaid accounts. Responsible for processing insurance claims...."
#      },
#      {
#       "title": "Accounts Payable Representative",
#       "hiringorganization": "Silvercote Lamination",
#       "name": "Silvercote Lamination",
#       "description": "Maintain historical records by filing processed invoices and voided checks as well as expense reports. Review past due invoices for required credit approval...."
#      },
#      {
#       "title": "Accounts Receivable Specialist",
#       "hiringorganization": "General Equipment and Supply",
#       "name": "General Equipment and Supply",
#       "description": "Experience in resolving invoice issues including, but not limited to customer disputes, short payments, proof of shipments, pass through of freight costs and..."
#      },
#      {
#       "title": "Accountant II",
#       "hiringorganization": "Greenville Health System",
#       "name": "Greenville Health System",
#       "description": "Bachelor's Degree in Accounting or related field with three (3) years Accounting, Finance, or related experience required...."
#      },
#      {
#       "title": "Analyst I/II-Finance",
#       "hiringorganization": "Windstream Communications",
#       "name": "Windstream Communications",
#       "description": "Post, edit, monitor and ensure bill messages are properly added to invoices. Ensure billing accuracy and timely issuance of invoices by providing analytical..."
#      },
#      {
#       "title": "Corporate Cost Accounting Manager",
#       "hiringorganization": "Hubbell Incorporated",
#       "name": "Hubbell Incorporated",
#       "description": "Responsible for month end closing journal entries and reports. Coordinate with corporate customs compliance any lighting accounting activities (duty assists,..."
#      },
#      {
#       "title": "FINANCIAL COORDINATOR Job",
#       "hiringorganization": "Bon Secours Health System",
#       "name": "Bon Secours Health System",
#       "description": "Must have at least 3 years customer service experience with insurance companies to include Medicare,. Standards, criteria, coding definitions and other..."
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "The City of Kenora's Asset Management Plan: From Development to ...",
#    "htmlTitle": "The City of Kenora&#39;s \u003cb\u003eAsset\u003c/b\u003e Management Plan: From Development to \u003cb\u003e...\u003c/b\u003e",
#    "link": "https://www.publicsectordigest.com/articles/view/1373/shareHash:1496%7C2e8d39532f01b20295963b3c15130952",
#    "displayLink": "www.publicsectordigest.com",
#    "snippet": "The Municipality of Grey Highlands' Asset Management Plan: From Development \nto Implementation. Karmen Krueger, Director of FinanceGrey Highlands.",
#    "htmlSnippet": "The Municipality of Grey Highlands&#39; \u003cb\u003eAsset\u003c/b\u003e Management Plan: From Development \u003cbr\u003e\nto Implementation. Karmen \u003cb\u003eKrueger\u003c/b\u003e, Director of FinanceGrey Highlands.",
#    "cacheId": "hWPG20l46G0J",
#    "formattedUrl": "https://www.publicsectordigest.com/.../shareHash: 1496%7C2e8d39532f01b20295963b3c15130952",
#    "htmlFormattedUrl": "https://www.publicsectordigest.com/.../shareHash: 1496%7C2e8d39532f01b20295963b3c15130952",
#    "pagemap": {
#     "postaladdress": [
#      {
#       "streetaddress": "148 Fullarton Street, Suite 1410",
#       "addresslocality": "London",
#       "addressregion": "Ontario",
#       "addresscountry": "Canada",
#       "postalcode": "N6A 5P3"
#      }
#     ],
#     "metatags": [
#      {
#       "twitter:card": "summary_large_image",
#       "twitter:title": "The City of Kenora's Asset Management Plan: From Development to Implementation",
#       "twitter:description": "Only 2.",
#       "twitter:image:src": "https://www.publicsectordigest.com/articles/articles/2014/5/kenora_casestudy-7.jpg",
#       "viewport": "width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0",
#       "og:site_name": "The Public Sector Digest",
#       "twitter:site": "@psdanalytics",
#       "twitter:creator": "@psdanalytics"
#      }
#     ],
#     "scholarlyarticle": [
#      {
#       "thumbnailurl": "https://www.publicsectordigest.com/img/articles/2014/5/kenora_casestudy-7.jpg",
#       "datepublished": "2014-05-15",
#       "name": "The City of Kenora's Asset Management Plan: From Development to Implementation",
#       "url": "The City of Kenora's Asset Management Plan: From Development to Implementation",
#       "description": "Only 2.5 hours from Winnipeg, the City of Kenora is one of Ontarios most westerly communities.Nestled in Northwestern Ontarios Lake of the Woods region, Kenora is a remote community that..."
#      },
#      {
#       "thumbnailurl": "https://www.publicsectordigest.com/img/articles/2014/6/gray-highlands-amp-cat.jpg",
#       "datepublished": "2014-06-01",
#       "name": "The Municipality of Grey Highlands' Asset Management Plan: From Development to Implementation",
#       "url": "The Municipality of Grey Highlands' Asset Management Plan: From Development to Implementation",
#       "description": "In 2012, the province of Ontario introduced a new program to help municipalities plan for the future and start to address the mounting infrastructure backlog. Ontario's Municipal Infrastructure..."
#      },
#      {
#       "thumbnailurl": "https://www.publicsectordigest.com/img/articles/2012/1/responsible_category.jpg",
#       "datepublished": "2012-01-18",
#       "name": "Responsible Asset Management in Dubai",
#       "url": "Responsible Asset Management in Dubai",
#       "description": "Should there be a greater sense of responsibility in asset management? This is one challenging question that should be proposed more often in the field of asset management. Thanks to the diligent..."
#      },
#      {
#       "thumbnailurl": "https://www.publicsectordigest.com/img/articles/2015/1/mcivor-cat.jpg",
#       "datepublished": "2015-01-01",
#       "name": "Achieving Corporate Objectives with Public Facilities",
#       "url": "Achieving Corporate Objectives with Public Facilities",
#       "description": "How government manages its real property assets is a concern taking on more prominence today. Canada is the second-largest country in landmass in the world and covers an area of 10 million..."
#      }
#     ],
#     "contactpoint": [
#      {
#       "telephone": "519-690-2565",
#       "faxnumber": "519-649-2010"
#      }
#     ]
#    }
#   },
#   {
#    "kind": "customsearch#result",
#    "title": "Allied Reliability Group | LinkedIn",
#    "htmlTitle": "Allied Reliability Group | LinkedIn",
#    "link": "http://eh.linkedin.com/company/allied-reliability?trk=company_logo",
#    "displayLink": "eh.linkedin.com",
#    "snippet": "Jon Krueger, Ali Al-Saleh +2 ... This is a great opportunity to improve upon your \ncurrent asset management and maintenance decision making! http://bit.ly/...",
#    "htmlSnippet": "Jon \u003cb\u003eKrueger\u003c/b\u003e, Ali \u003cb\u003eAl\u003c/b\u003e-Saleh +2 ... This is a great opportunity to improve upon your \u003cbr\u003e\ncurrent \u003cb\u003easset\u003c/b\u003e management and maintenance decision making! http://bit.ly/&nbsp;...",
#    "cacheId": "Qfd6RaXQH6MJ",
#    "formattedUrl": "eh.linkedin.com/company/allied-reliability?trk=company_logo",
#    "htmlFormattedUrl": "eh.linkedin.com/company/allied-reliability?trk=company_logo",
#    "pagemap": {
#     "cse_image": [
#      {
#       "src": "http://m.c.lnkd.licdn.com/media/p/4/005/037/106/2f4d95e.png"
#      }
#     ],
#     "cse_thumbnail": [
#      {
#       "width": "385",
#       "height": "131",
#       "src": "https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcTAFzIqL279UQD1levOmZmDKp4tzGugN4YomKYbZ72hEh9Y42noAPJVOaVt"
#      }
#     ],
#     "postaladdress": [
#      {
#       "streetaddress": "4200 Faber Place Drive",
#       "addresslocality": "Charleston,",
#       "addressregion": "SC",
#       "postalcode": "29405",
#       "addresscountry": "United States"
#      }
#     ],
#     "metatags": [
#      {
#       "globaltrackingurl": "//www.linkedin.com/mob/tracking",
#       "globaltrackingappname": "biz",
#       "globaltrackingappid": "webTracking",
#       "lnkd-track-json-lib": "http://s.c.lnkd.licdn.com/scds/concat/common/js?v=build-2000_8_48795-prod&f=lib%2Fjson%2Fjson2&f=lib%2Ferror-tracking%2F1.0.0%2Fshared%2Fxhr.min&fc=2",
#       "treeid": "ntW6uMJn7hOgoCuEXisAAA==",
#       "appname": "biz",
#       "pageimpressionid": "62f9559a-bf98-47d6-9457-9909a90a3423",
#       "pagekey": "biz-overview-company-public",
#       "analyticsurl": "/analytics/noauthtracker",
#       "msapplication-tileimage": "http://s.c.lnkd.licdn.com/scds/common/u/images/logos/linkedin/logo-in-win8-tile-144_v1.png",
#       "msapplication-tilecolor": "#0077B5",
#       "application-name": "LinkedIn",
#       "remote-nav-init-marker": "true",
#       "og:image": "http://m.c.lnkd.licdn.com/mpr/mpr/shrink_200_100/AAEAAQAAAAAAAALDAAAAJDA0MGRhYTFmLTBiZGQtNDRiZS1iMzI5LTg5YmE5NjA1MWFkMw.png",
#       "og:description": "Reliability its in our DNA.    Allied Reliability Group offers best-in-industry maintenance, reliability, and operational consulting and services, training, staffing, and integrated software solutions servicing the industrial and manufacturing sector.    Our Vision Statement  Be the global partner for operational reliability solutions.    Our Mission Statement  For our customers, employees, and shareholders, we will:   Understand each and their needs    Deliver superior technical capabilities    Demonstrate increasing value    Our Locations:    Allied Reliability Group Global Headquarters    4200 Faber Place Drive  Charleston, SC 29405  Phone: +1.843.414.5760  Fax: +1 843.414.5779  E-mail: info@alliedreliability.com       Allied Reliability Group EMEA    Interleuvenlaan 64  3001 Heverlee, Belgium  Phone: +32 (0)16 40 01 36  Fax: +32 (0)16 40 01 37  E-mail: info_emea@alliedreliability.com    Allied Reliability Group Canada    2572 Daniel Johnson, 2nd Floor  Laval, QC, Canada  H7T 2R3  Phone: +1.",
#       "og:type": "article",
#       "og:title": "Allied Reliability Group",
#       "og:url": "http://eh.linkedin.com/company/allied-reliability"
#      }
#     ],
#     "corporation": [
#      {
#       "name": "Allied Reliability Group"
#      }
#     ]
#    }
#   }
#  ]
# }

# %% [markdown]
# tangent: [Natalie Portman tells Harvard seniors to use inexperience as an asset - The Boston Globe](https://www.bostonglobe.com/lifestyle/names/2015/05/27/natalie-portman-tells-harvard-seniors-use-inexperience-asset/GS5LQ3rgc15FEJgLuisYFJ/story.htm)

# %% [markdown]
# **Reviewing the result with search hits**
#
# Here we can see some similarities as well. It seems like we get into trouble when trying to
# assess the fields within the 'pagemap'. It seems as though the 'snippet' field may be sufficient
# for our needs.
#
# This information seems to be sufficient for creating the next version of the parser. We have
# been able to indentify fields that occur in each result. We have also found fields that occur
# in each search hit.
#
# At this stage, parsing the 'pagemap' seems to be unecessary.

# %% [markdown]
# ## Building a better document converter

# %%
# meta information
import json
pydict = read_json(resultspath)

valuedict = json.loads(pydict[pydict.keys()[0]])

# %%
print("search results: {}".format(valuedict['items'][0]))
# Out:
# search results: {u'kind': u'customsearch#result', u'title': u'Honda Village - Auto Repair - Newton Corner, MA - Reviews ...', u'displayLink': u'www.yelp.com', u'htmlTitle': u'Honda Village - Auto Repair - Newton Corner, MA - Reviews <b>...</b>', u'formattedUrl': u'www.yelp.com/biz/honda-village-newton-corner', u'htmlFormattedUrl': u'www.yelp.com/biz/honda-village-newton-corner', u'pagemap': {u'rating': [{u'ratingvalue': u'5.0'}, {u'ratingvalue': u'5.0'}, {u'ratingvalue': u'5.0'}, {u'ratingvalue': u'5.0'}, {u'ratingvalue': u'1.0'}, {u'ratingvalue': u'5.0'}, {u'ratingvalue': u'5.0'}, {u'ratingvalue': u'4.0'}, {u'ratingvalue': u'5.0'}, {u'ratingvalue': u'1.0'}, {u'ratingvalue': u'2.0'}, {u'ratingvalue': u'5.0'}, {u'ratingvalue': u'4.0'}, {u'ratingvalue': u'1.0'}, {u'ratingvalue': u'5.0'}, {u'ratingvalue': u'4.0'}, {u'ratingvalue': u'1.0'}, {u'ratingvalue': u'4.0'}, {u'ratingvalue': u'5.0'}, {u'ratingvalue': u'1.0'}, {u'ratingvalue': u'2.0'}, {u'ratingvalue': u'5.0'}, {u'ratingvalue': u'5.0'}, {u'ratingvalue': u'1.0'}, {u'ratingvalue': u'1.0'}, {u'ratingvalue': u'5.0'}, {u'ratingvalue': u'5.0'}, {u'ratingvalue': u'5.0'}, {u'ratingvalue': u'2.0'}, {u'ratingvalue': u'2.0'}, {u'ratingvalue': u'1.0'}, {u'ratingvalue': u'2.0'}, {u'ratingvalue': u'1.0'}, {u'ratingvalue': u'1.0'}, {u'ratingvalue': u'5.0'}, {u'ratingvalue': u'2.0'}, {u'ratingvalue': u'2.0'}, {u'ratingvalue': u'4.0'}, {u'ratingvalue': u'1.0'}, {u'ratingvalue': u'5.0'}], u'breadcrumb': [{u'url': u'Automotive', u'title': u'Automotive'}, {u'url': u'Auto Repair', u'title': u'Auto Repair'}, {u'url': u'Automotive', u'title': u'Automotive'}, {u'url': u'Car Dealers', u'title': u'Car Dealers'}], u'metatags': [{u'twitter:app:name:googleplay': u'Yelp', u'og:type': u'yelpyelp:business', u'og:image:height': u'498', u'application-name': u'Yelp', u'twitter:domain': u'yelp.com', u'twitter:site': u'@yelp', u'twitter:app:url:ipad': u'yelp:///biz/EkjITiBxgyTVxy_NWZJyJw?campaign=default&source=twitter-card&utm_campaign=default&utm_source=twitter-card', u'twitter:app:url:googleplay': u'android-app://com.yelp.android/yelp-app-indexing/biz/EkjITiBxgyTVxy_NWZJyJw?utm_medium=organic&utm_source=google', u'fb:app_id': u'97534753161', u'msapplication-navbutton-color': u'#c41200', u'msapplication-task': u'name=Find Reviews; action-uri=/; icon-uri=http://s3-media1.fl.yelpcdn.com/assets/2/www/img/a6bbc59c7458/ico/favicon-16x16.ico', u'og:url': u'http://www.yelp.com/biz/honda-village-newton-corner', u'twitter:app:url:iphone': u'yelp:///biz/EkjITiBxgyTVxy_NWZJyJw?campaign=default&source=twitter-card&utm_campaign=default&utm_source=twitter-card', u'twitter:app:name:iphone': u'Yelp', u'msapplication-tilecolor': u'#c41200', u'apple-itunes-app': u'app-id=284910350, app-argument=yelp:///biz/EkjITiBxgyTVxy_NWZJyJw?campaign=default&source=www&utm_campaign=default&utm_source=www', u'msapplication-window': u'width=1024;height=768', u'viewport': u'width=1020', u'og:title': u'Honda Village - Newton Corner, MA', u'twitter:app:id:ipad': u'id284910350', u'msapplication-tooltip': u'Go to Yelp.com', u'og:image:width': u'1142', u'twitter:app:name:ipad': u'Yelp', u'msapplication-tileimage': u'http://s3-media3.fl.yelpcdn.com/assets/2/www/img/7f906850f02b/ico/win8-tile.png', u'msapplication-starturl': u'http://www.yelp.com/', u'twitter:app:id:googleplay': u'com.yelp.android', u'og:image': u'http://s3-media2.fl.yelpcdn.com/bphoto/ciCFr6ZIplthauOv8MSNBg/o.jpg', u'twitter:app:id:iphone': u'id284910350', u'theme-color': u'#c41200', u'og:site_name': u'Yelp', u'twitter:card': u'summary', u'og:description': u"Specialties: For 40+ years now, Honda Village has been proud to present one of the world's truly great line-up of automobiles in a convenient and fun atmosphere.  We are tucked into Newton Corner, incredibly close by for most of greater\u2026", u'yelp-biz-id': u'EkjITiBxgyTVxy_NWZJyJw'}], u'review': [{u'ratingstars': u'3.0', u'ratingcount': u'95'}, {u'datepublished': u'2015-05-17', u'description': u"Last month I purchased a 20 ...

# %%
print("some metadata: {}".format(valuedict['items'][0].keys()))
# Out:
# some metadata: [u'kind', u'title', u'displayLink', u'htmlTitle', u'formattedUrl', u'htmlFormattedUrl', u'pagemap', u'snippet', u'htmlSnippet', u'link', u'cacheId']

# %% [markdown]
# ### Metadata for ES document

# %%
print('kind: {}'.format(valuedict['kind']))
print('template: {}'.format(valuedict['url']['template'])) #make raw
print('title: {}'.format(valuedict['queries']['request'][0]['title']))
print('totalResults: {}'.format(valuedict['queries']['request'][0]['totalResults']))
print('searchTerms: {}'.format(valuedict['queries']['request'][0]['searchTerms']))
print('count: {}'.format(valuedict['queries']['request'][0]['count']))
print('language: {}'.format(valuedict['queries']['request'][0]['language']))
print('inputEncoding: {}'.format(valuedict['queries']['request'][0]['inputEncoding']))
print('outputEncoding: {}'.format(valuedict['queries']['request'][0]['outputEncoding']))
print('safe: {}'.format(valuedict['queries']['request'][0]['safe']))
print('cx: {}'.format(valuedict['queries']['request'][0]['cx']))
print('filter: {}'.format(valuedict['queries']['request'][0]['filter']))
print('exactTerms: {}'.format(valuedict['queries']['request'][0]['exactTerms']))
print('dateRestrict: {}'.format(valuedict['queries']['request'][0]['dateRestrict']))
print('searchTime: {}'.format(valuedict['searchInformation']['searchTime']))
print('formattedSearchTime: {}'.format(valuedict['searchInformation']['formattedSearchTime']))
print('totalResults: {}'.format(valuedict['searchInformation']['totalResults']))
# Out:
# kind: customsearch#search
# template: https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&cref={cref?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json
# title: Google Custom Search - Kelley Mote
# totalResults: 426
# searchTerms: Kelley Mote
# count: 10
# language: lang_en
# inputEncoding: utf8
# outputEncoding: utf8
# safe: off
# cx: 003891126258438650518:fcb7zxrqavu
# filter: 1
# exactTerms: asset
# dateRestrict: '2012'
# searchTime: 0.710357
# formattedSearchTime: 0.71
# totalResults: 426

# %% [markdown]
# ### Resultdata for ES document

# %%
print('kind: {}'.format(valuedict['kind']))
print('cx: {}'.format(valuedict['queries']['request'][0]['cx']))
print('title: {}'.format(valuedict['items'][0]['title']))
print('link: {}'.format(valuedict['items'][0]['link'])) #make raw
print('snippet: {}'.format(codecs.encode(valuedict['items'][0]['snippet'],'ascii','ignore')))
# Out:
# kind: customsearch#search
# cx: 003891126258438650518:fcb7zxrqavu
# title: Honda Village - Auto Repair - Newton Corner, MA - Reviews ...
# link: http://www.yelp.com/biz/honda-village-newton-corner
# snippet: Find Out More About Our Trade Up Special! .... If there were more Jims in the car
# sales world, I think the public would have a much higher opinion of car...

# %% [markdown]
# ## Results from Elasticsearch document conversion

# %%
# prepare all documents for bulk upload into elasticsearch
#actions = prepare_all_documents(results, esformat, read_csv(filepath, QUERY_LIMIT))

# %%
# it's pretty clear from steping through the documents that
# there are some issues with the parser. The first version
# definitely worked better than nothing but we are going to
# need to make some changes.

#actions[47]['_source']
